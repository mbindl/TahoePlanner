# %% [markdown]
# # Setup

# %%
# import packages and modules
import os
import csv
from datetime import datetime
import pyodbc
import arcpy
from arcgis.features import GeoAccessor, GeoSeriesAccessor
import pickle
import pandas as pd
from functools import reduce

# set data frame display options
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.options.display.float_format = '{:,.2f}'.format

# set overwrite to true
arcpy.env.overwriteOutput = True

# in memory output file path
wk_memory = "in_memory" + "\\"

# set workspace and sde connections 
scratchFolder = "C:\\GIS\\PROJECT\\ScratchPaper"
workspace     = "C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb"
arcpy.env.workspace = "C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb"

## SDE Connection Files saved on the Network
# sdeTabular = "F:\\GIS\\GIS_DATA\\Tabular.sde"
# sdeBase    = "F:\\GIS\\GIS_DATA\\Vector.sde"
# sdeCollect = "F:\\GIS\\GIS_DATA\\Collect.sde"

# network path to connection files
filePath = "C:\\GIS\\DB_CONNECT"

# database file path 
sdeBase = os.path.join(filePath, "Vector.sde")
sdeCollect = os.path.join(filePath, "Collection.sde")

# %%
def fieldJoinCalc(updateFC, updateFieldsList, sourceFC, sourceFieldsList):
    from time import strftime  
    print ("Started data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))
   
    # Use list comprehension to build a dictionary from a da SearchCursor  
    valueDict = {r[0]:(r[1:]) for r in arcpy.da.SearchCursor(sourceFC, sourceFieldsList)}  
   
    with arcpy.da.UpdateCursor(updateFC, updateFieldsList) as updateRows:  
        for updateRow in updateRows:  
            # store the Join value of the row being updated in a keyValue variable  
            keyValue = updateRow[0]  
            # verify that the keyValue is in the Dictionary  
            if keyValue in valueDict:  
                # transfer the value stored under the keyValue from the dictionary to the updated field.  
                updateRow[1] = valueDict[keyValue][0]  
                updateRows.updateRow(updateRow)    
    del valueDict  
    print ("Finished data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))

# %% [markdown]
# ## Get a Copy of Parcel Master

# %%
# copy parcel master to local gdb
# parcel base
parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcel_Master"
# copy
arcpy.FeatureClassToFeatureClass_conversion(parcels, workspace,"ParcelMaster")
# Out:
# <Result 'C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb\\ParcelMaster'>

# %%
# create spatial dataframe from parcel feature class
sdfParcels = pd.DataFrame.spatial.from_featureclass('ParcelMaster')
sdfParcels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61263 entries, 0 to 61262
# Data columns (total 62 columns):
# OBJECTID                          61263 non-null int64
# APN                               61263 non-null object
# PPNO                              61263 non-null float64
# HSE_NUMBR                         61263 non-null int64
# UNIT_NUMBR                        61263 non-null object
# STR_DIR                           61263 non-null object
# STR_NAME                          61263 non-null object
# STR_SUFFIX                        61263 non-null object
# APO_ADDRESS                       61263 non-null object
# PSTL_TOWN                         61263 non-null object
# PSTL_STATE                        61263 non-null object
# PSTL_ZIP5                         61263 non-null object
# OWN_FIRST                         61263 non-null object
# OWN_LAST                          61263 non-null object
# OWN_FULL                          61263 non-null object
# MAIL_ADD1                         61263 non-null object
# MAIL_ADD2                         61263 non-null object
# MAIL_CITY                         61263 non-null object
# MAIL_STATE                        61263 non-null object
# MAIL_ZIP5                         61263 non-null object
# JURISDICTION                      61263 non-null object
# COUNTY                            61263 non-null object
# OWNERSHIP_TYPE                    61263 non-null object
# COUNTY_LANDUSE_CODE               61263 non-null object
# COUNTY_LANDUSE_DESCRIPTION        61263 non-null object
# TRPA_LANDUSE_DESCRIPTION          61261 non-null object
# REGIONAL_LANDUSE                  61263 non-null object
# UNITS                             61263 non-null object
# BEDROOMS                          61263 non-null object
# BATHROOMS                         61263 non-null object
# ALLOWABLE_COVERAGE_BAILEY_SQFT    61256 non-null float64
# IMPERVIOUS_SURFACE_SQFT           61263 non-null float64
# SOIL_1974                         61263 non-null object
# SOIL_2003                         61263 non-null object
# HRA_NAME                          61263 non-null object
# WATERSHED_NUMBER                  61263 non-null int64
# WATERSHED_NAME                    61263 non-null object
# PRIORITY_WATERSHED                61263 non-null object
# FIREPD                            61263 non-null object
# WITHIN_TRPA_BNDY                  61263 non-null int64
# LITTORAL                          61263 non-null int64
# AS_LANDVALUE                      61263 non-null int64
# AS_IMPROVALUE                     61263 non-null int64
# AS_SUM                            61263 non-null int64
# TAX_LANDVALUE                     61263 non-null int64
# TAX_IMPROVALUE                    61263 non-null int64
# TAX_SUM                           61263 non-null int64
# TAX_YEAR                          61263 non-null object
# PLAN_ID                           61263 non-null object
# PLAN_NAME                         61263 non-null object
# ZONING_ID                         61263 non-null object
# ZONING_DESCRIPTION                61263 non-null object
# TOWN_CENTER                       61263 non-null object
# LOCATION_TO_TOWNCENTER            61263 non-null object
# INDEX_1987                        61263 non-null object
# LOCAL_PLAN_HYPERLINK              61263 non-null object
# DESIGN_GUIDELINES_HYPERLINK       61263 non-null object
# INDEX_1987_HYPERLINK              61263 non-null object
# PARCEL_ACRES                      61263 non-null float64
# PARCEL_SQFT                       61263 non-null float64
# LTINFO_HYPERLINK                  61263 non-null object
# SHAPE                             61263 non-null geometry
# dtypes: float64(5), geometry(1), int64(11), object(45)
# memory usage: 29.0+ MB

# %% [markdown]
# ## Get LTInfo Data Frames

# %%
# create dataframes from https://qa.laketahoeinfo.org/WebServices/List
dfLTAPN    = pd.read_json("https://laketahoeinfo.org/WebServices/GetAllParcels/JSON/e17aeb86-85e3-4260-83fd-a2b32501c476")
dfIPES     = pd.read_json("https://laketahoeinfo.org/WebServices/GetParcelIPESScores/JSON/e17aeb86-85e3-4260-83fd-a2b32501c476")
dfLCV      = pd.read_json("https://laketahoeinfo.org/WebServices/GetParcelsByLandCapability/JSON/e17aeb86-85e3-4260-83fd-a2b32501c476")
dfDevBank  = pd.read_json("https://laketahoeinfo.org/WebServices/GetBankedDevelopmentRights/JSON/e17aeb86-85e3-4260-83fd-a2b32501c476")

# %% [markdown]
# ### Dump Pickles

# %%
# dump pickle of merged dataframe
with open(os.path.join(scratchFolder, "sdfParcels.pickle"), 'wb') as f:
    pickle.dump(sdfParcels, f)
    
# dump pickle of merged dataframe
with open(os.path.join(scratchFolder, "dfLTAPN.pickle"), 'wb') as f:
    pickle.dump(dfLTAPN, f)

# dump pickle of merged dataframe
with open(os.path.join(scratchFolder, "dfIPES.pickle"), 'wb') as f:
    pickle.dump(dfIPES, f)

# dump pickle of merged dataframe
with open(os.path.join(scratchFolder, "dfLCV.pickle"), 'wb') as f:
    pickle.dump(dfLCV, f)
    
# dump pickle of merged dataframe
with open(os.path.join(scratchFolder, "dfDevBank.pickle"), 'wb') as f:
    pickle.dump(dfDevBank, f)

# %% [markdown]
# ### Load Pickles

# %%
with open(os.path.join(scratchFolder, "sdfParcels.pickle"), 'rb') as f:
    sdfParcels = pickle.load(f)

with open(os.path.join(scratchFolder, "dfLTAPN.pickle"), 'rb') as f:
    dfLTAPN = pickle.load(f)

with open(os.path.join(scratchFolder, "dfIPES.pickle"), 'rb') as f:
    dfIPES = pickle.load(f)
    
with open(os.path.join(scratchFolder, "dfLCV.pickle"), 'rb') as f:
    dfLCV = pickle.load(f)

with open(os.path.join(scratchFolder, "dfDevBank.pickle"), 'rb') as f:
    dfDevBank = pickle.load(f)

# %% [markdown]
# # Accela to SDE

# %% [markdown]
# ## BMP Status Update

# %%
sdfParcels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61263 entries, 0 to 61262
# Data columns (total 62 columns):
# OBJECTID                          61263 non-null int64
# APN                               61263 non-null object
# PPNO                              61263 non-null float64
# HSE_NUMBR                         61263 non-null int64
# UNIT_NUMBR                        61263 non-null object
# STR_DIR                           61263 non-null object
# STR_NAME                          61263 non-null object
# STR_SUFFIX                        61263 non-null object
# APO_ADDRESS                       61263 non-null object
# PSTL_TOWN                         61263 non-null object
# PSTL_STATE                        61263 non-null object
# PSTL_ZIP5                         61263 non-null object
# OWN_FIRST                         61263 non-null object
# OWN_LAST                          61263 non-null object
# OWN_FULL                          61263 non-null object
# MAIL_ADD1                         61263 non-null object
# MAIL_ADD2                         61263 non-null object
# MAIL_CITY                         61263 non-null object
# MAIL_STATE                        61263 non-null object
# MAIL_ZIP5                         61263 non-null object
# JURISDICTION                      61263 non-null object
# COUNTY                            61263 non-null object
# OWNERSHIP_TYPE                    61263 non-null object
# COUNTY_LANDUSE_CODE               61263 non-null object
# COUNTY_LANDUSE_DESCRIPTION        61263 non-null object
# TRPA_LANDUSE_DESCRIPTION          61261 non-null object
# REGIONAL_LANDUSE                  61263 non-null object
# UNITS                             61263 non-null object
# BEDROOMS                          61263 non-null object
# BATHROOMS                         61263 non-null object
# ALLOWABLE_COVERAGE_BAILEY_SQFT    61256 non-null float64
# IMPERVIOUS_SURFACE_SQFT           61263 non-null float64
# SOIL_1974                         61263 non-null object
# SOIL_2003                         61263 non-null object
# HRA_NAME                          61263 non-null object
# WATERSHED_NUMBER                  61263 non-null int64
# WATERSHED_NAME                    61263 non-null object
# PRIORITY_WATERSHED                61263 non-null object
# FIREPD                            61263 non-null object
# WITHIN_TRPA_BNDY                  61263 non-null int64
# LITTORAL                          61263 non-null int64
# AS_LANDVALUE                      61263 non-null int64
# AS_IMPROVALUE                     61263 non-null int64
# AS_SUM                            61263 non-null int64
# TAX_LANDVALUE                     61263 non-null int64
# TAX_IMPROVALUE                    61263 non-null int64
# TAX_SUM                           61263 non-null int64
# TAX_YEAR                          61263 non-null object
# PLAN_ID                           61263 non-null object
# PLAN_NAME                         61263 non-null object
# ZONING_ID                         61263 non-null object
# ZONING_DESCRIPTION                61263 non-null object
# TOWN_CENTER                       61263 non-null object
# LOCATION_TO_TOWNCENTER            61263 non-null object
# INDEX_1987                        61263 non-null object
# LOCAL_PLAN_HYPERLINK              61263 non-null object
# DESIGN_GUIDELINES_HYPERLINK       61263 non-null object
# INDEX_1987_HYPERLINK              61263 non-null object
# PARCEL_ACRES                      61263 non-null float64
# PARCEL_SQFT                       61263 non-null float64
# LTINFO_HYPERLINK                  61263 non-null object
# SHAPE                             61263 non-null geometry
# dtypes: float64(5), geometry(1), int64(11), object(45)
# memory usage: 29.0+ MB

# %%
# start timer
startTimer = datetime.now()

# name of feature class
outFC = "Parcel_BMP"

# make sql database connection with pyodbc
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=sql14;DATABASE=tahoebmpsde;UID=sde;PWD=staff')

# create dataframe from sql query
dfSQL = pd.read_sql("SELECT * FROM tahoebmpsde.dbo.v_BMPStatus", conn)

# specify sde connection file
sdeBase = "C:\\GIS\\DB_CONNECT\\Vector.sde"

# create spatial dataframe from parcels in sde
parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcel_Master"
sdfParcels = pd.DataFrame.spatial.from_featureclass(parcels)

# merge parcels and sql table on APN
df = pd.merge(sdfParcels, dfSQL, on='APN', how='inner')

# specify fields to keep
dfOut = df[['APN',
            'JURISDICTION',
            'ZONING_ID',
            'PLAN_NAME',
            'TOWN_CENTER',
            'CertificateIssued',
            'EvaluationComplete',
            'SourceCertIssued',
            'CertDate',
            'CertReissuedDate',
            'LandUse',
            'BMPStatus',
            'Catchment',
            'SourceCertDate',
            'SiteConstraint',
            'CreditPercent',
            'AreaWide',
            'CreditArea',
            'TMDL_LandUse',
            'CertNo',
            'SHAPE'
            ]].copy()

# delete output fc if exists
if arcpy.Exists(outFC):
    arcpy.Delete_management(outFC)

# spaital dataframe to feature class
dfOut.spatial.to_featureclass(outFC)

# confirm feature class was created
print("\nUpdated " + outFC)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print("\nTime it took to run this script: {}".format(endTimer))
# Out:
# Updated Parcel_BMP
#
# Time it took to run this script: 0:03:28.996381

# %%
# start timer
startTimer = datetime.now()

## Set the Local Variables
#------------------------------------------------------------------------------------------------------#
# Change this to the path of your input feature class
inputfc = "Parcel_BMP"

# Change this to the path of your output FC
outfc = sdeCollect + "\\sde_collection.SDE.Parcel\\sde_collection.SDE.Parcel_BMP"

# feature dataset to unversion and register as version
fdata = sdeCollect + "\\sde_collection.SDE.Parcel"

fieldnames =  ['APN',
            'JURISDICTION',
            'ZONING_ID',
            'PLAN_NAME',
            'TOWN_CENTER',
            'CertificateIssued',
            'EvaluationComplete',
            'SourceCertIssued',
            'CertDate',
            'CertReissuedDate',
            'LandUse',
            'BMPStatus',
            'Catchment',
            'SourceCertDate',
            'SiteConstraint',
            'CreditPercent',
            'AreaWide',
            'CreditArea',
            'TMDL_LandUse',
            'CertNo',
            'SHAPE@']

#--------------------------------------------------------------------------------------------------------#

# disconnect all users
print("\nDisconnecting all users...")
arcpy.DisconnectUser(sdeCollect, "ALL")

print ("Unregistering feature dataset as versioned...")
# unregister the sde feature class as versioned
arcpy.UnregisterAsVersioned_management(fdata,"NO_KEEP_EDIT","COMPRESS_DEFAULT")
print ("Finished unregistering feature dataset as versioned.")
# set overwrite files envrionment setting to True
arcpy.env.overwriteOutput = True

# deletes all rows from the SDE feature class
arcpy.TruncateTable_management(outfc)
print ("\nDeleted all records in: {}\n".format(outfc))

# insert rows from Temporary feature class to SDE feature class
with arcpy.da.InsertCursor(outfc, fieldnames) as oCursor:
    count = 0
    with arcpy.da.SearchCursor(inputfc, fieldnames) as iCursor:
        for row in iCursor:
            oCursor.insertRow(row)
            count += 1
            if count % 1000 == 0:
                print("Inserting record {0} into SDE feature class".format(count))
# disconnect all users
print("\nDisconnecting all users...")
arcpy.DisconnectUser(sdeCollect, "ALL")

print("\nRegistering feature dataset as versioned...")
# register SDE feature class as versioned
arcpy.RegisterAsVersioned_management(fdata, "NO_EDITS_TO_BASE")
print("\nFinished registering feature dataset as versioned.")

# confirm feature class was created
print("\nUpdated " + outfc)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print ("\nTime it took to run this script: {}".format(endTimer))
# Out:
# Disconnecting all users...
# Unregistering feature dataset as versioned...
# Finished unregistering feature dataset as versioned.
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# <ipython-input-37-b36cb2328f60> in <module>
#      49
#      50 # deletes all rows from the SDE feature class
# ---> 51 arcpy.TruncateTable_management(outfc)
#      52 print ("\nDeleted all records in: {}\n".format(outfc))
#      53
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in TruncateTable(in_table)
#   19857         return retval
#   19858     except Exception as e:
# > 19859         raise e
#   19860
#   19861
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in TruncateTable(in_table)
#   19854     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#   19855     try:
# > 19856         retval = convertArcObjectToPythonObject(gp.TruncateTable_management(*gp_fixargs((in_table,), True)))
#   19857         return retval
#   19858     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     509         val = getattr(self._gp, attr)
#     510         if callable(val):
# --> 511             return lambda *args: val(*gp_fixargs(args, True))
#     512         else:
#     513             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# The featureclass was not found.
# Failed to execute (TruncateTable).

# %% [markdown]
# ## LCV Update

# %%
# start timer
startTimer = datetime.now()

# name of feature class
name = "Parcel_LCV"
# specify output feature class
outFC = '//Arcprod/C$/GISData/PermitReview_AppData.gdb/' + name
# outFC = "C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb\\" + name


# make sql database connection with pyodbc
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};SERVER=ASQL;DATABASE=Accela;UID=BMP_Update;PWD=BMP_update_123')

# create dataframe from sql query
dfSQL = pd.read_sql("SELECT * FROM Accela.dbo.v_LandCapabilityVerifications", conn)

# specify sde connection file
sdeBase = "C:\\GIS\\DB_CONNECT\\Vector.sde"

# create spatial dataframe from parcels in sde
parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Base"
sdfParcels = pd.DataFrame.spatial.from_featureclass(parcels)

# merge parcels and sql table on APN
df = pd.merge(sdfParcels, dfSQL, left_on='APN', right_on='GIS_ID', how='inner')

# rename some of the fields
df.rename(columns={"LABEL_FIELD": "Status"}, inplace=True)

# specify fields to keep
dfOut = df[["APN", "Status", "SHAPE"]].copy()

# delete output fc if exists
if arcpy.Exists(outFC):
    arcpy.Delete_management(outFC)

# spaital dataframe to feature class
dfOut.spatial.to_featureclass(outFC)

# confirm feature class was created
print("\nUpdated " + outFC)

# %% [markdown]
# ## LCV Challenge Update

# %%
# start timer
startTimer = datetime.now()

# name of feature class
name = "Parcel_LCV_Challenge"
# specify output feature class
outFC = '//Arcprod/C$/GISData/PermitReview_AppData.gdb/' + name
# outFC = "C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb\\" + name

# make sql database connection with pyodbc
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};SERVER=ASQL;DATABASE=Accela;UID=BMP_Update;PWD=BMP_update_123')

# create dataframe from sql query
dfSQL = pd.read_sql("SELECT * FROM Accela.dbo.v_LandCapabilityChallenges", conn)

# specify sde connection file
sdeBase = "F:\\GIS\\GIS_DATA\\Vector.sde"

# create spatial dataframe from parcels in sde
parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Base"
sdfParcels = pd.DataFrame.spatial.from_featureclass(parcels)

# merge parcels and sql table on APN
df = pd.merge(sdfParcels, dfSQL, left_on='APN', right_on='GIS_ID', how='inner')

# rename some of the fields
df.rename(columns={"REC_DATE": "Date", "LABEL_FIELD": "Status"}, inplace=True)

# specify fields to keep
dfOut = df[["APN", "Date", "Status", "SHAPE"]].copy()

# delete output fc if exists
if arcpy.Exists(outFC):
    arcpy.Delete_management(outFC)

# spaital dataframe to feature class
dfOut.spatial.to_featureclass(outFC)

# confirm feature class was created
print("\nUpdated " + outFC)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print("\nTime it took to run this script: {}".format(endTimer))

# %% [markdown]
# ## Soils Hydro Update

# %%
# start timer
startTimer = datetime.now()

# name of feature class
name = "Parcel_SoilsHydro"
# specify output feature class
outFC = '//Arcprod/C$/GISData/PermitReview_AppData.gdb/' + name
# outFC = "C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb\\" + name

# make sql database connection with pyodbc
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};SERVER=ASQL;DATABASE=Accela;UID=BMP_Update;PWD=BMP_update_123')

# create dataframe from sql query
dfSQL = pd.read_sql("SELECT * FROM Accela.dbo.v_HydroSoilsProjects", conn)

# specify sde connection file
sdeBase = "F:\\GIS\\GIS_DATA\\Vector.sde"

# create spatial dataframe from parcels in sde
parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Base"
sdfParcels = pd.DataFrame.spatial.from_featureclass(parcels)

# merge parcels and sql table on APN
df = pd.merge(sdfParcels, dfSQL, left_on='APN', right_on='GIS_ID', how='inner')

# rename some of the fields
df.rename(columns={"REC_DATE": "Date", "LABEL_FIELD": "Status"}, inplace=True)

# specify fields to keep
dfOut = df[["APN", "Date", "Status", "SHAPE"]].copy()

# delete output fc if exists
if arcpy.Exists(outFC):
    arcpy.Delete_management(outFC)

# spaital dataframe to feature class
dfOut.spatial.to_featureclass(outFC)

# confirm feature class was created
print("\nUpdated " + outFC)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print("\nTime it took to run this script: {}".format(endTimer))

# %% [markdown]
# ## Production Script

# %%
"""
ETL_Accella_To_SDE.py
March 13th, 2020
Mason Bindl, Tahoe Regional Planning Agency

This python script was developed to move data from 
Accela to TRPA's Enterprise Geodatabase, Collection.sde

This script uses Python 3.x and was designed to be used with 
the default ArcGIS Pro python enivorment "arcgispro-py3", with
no need for installing new libraries.

"""

## This script updates parcel specific feature classes for BMPs, LCVs, LCCs, Historic Parcels,
# Import system modules
import pandas as pd
import pyodbc
import arcpy
from arcgis.features import GeoAccessor, GeoSeriesAccessor
from datetime import datetime

# set workspace and sde connections
sdeBase = "F:\\GIS\\GIS_DATA\\Vector.sde"

# start timer
startTimer = datetime.now()

# name of feature class
name = "Parcel_BMP"
# specify output feature class
outFC = '//Arcprod/C$/GISData/PermitReview_AppData.gdb/' + name
# outFC = "C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb\\" + name

# make sql database connection with pyodbc
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=sql14;DATABASE=tahoebmpsde;UID=sde;PWD=staff')

# create dataframe from sql query
dfSQL = pd.read_sql("SELECT * FROM tahoebmpsde.dbo.v_BMPStatus", conn)

# specify sde connection file
sdeBase = "C:\\GIS\\DB_CONNECT\\Vector.sde"

# create spatial dataframe from parcels in sde
parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Base"
sdfParcels = pd.DataFrame.spatial.from_featureclass(parcels)

# merge parcels and sql table on APN
df = pd.merge(sdfParcels, dfSQL, on='APN', how='inner')

# specify fields to keep
dfOut = df[['APN',
            'JURISDICTION',
            'CertificateIssued',
            'EvaluationComplete',
            'SourceCertIssued',
            'CertDate',
            'CertReissuedDate',
            'LandUse',
            'BMPStatus',
            'Catchment',
            'SourceCertDate',
            'SiteConstraint',
            'CreditPercent',
            'AreaWide',
            'CreditArea',
            'TMDL_LandUse',
            'CertNo',
            'SHAPE'
            ]].copy()

# delete output fc if exists
if arcpy.Exists(outFC):
    arcpy.Delete_management(outFC)

# spaital dataframe to feature class
dfOut.spatial.to_featureclass(outFC)

# confirm feature class was created
print("\nUpdated " + outFC)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print("\nTime it took to run this script: {}".format(endTimer))

# -------------------------------------------------------------- #

# start timer
startTimer = datetime.now()

# name of feature class
name = "Parcel_LCV"
# specify output feature class
outFC = '//Arcprod/C$/GISData/PermitReview_AppData.gdb/' + name
# outFC = "C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb\\" + name


# make sql database connection with pyodbc
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};SERVER=ASQL;DATABASE=Accela;UID=BMP_Update;PWD=BMP_update_123')

# create dataframe from sql query
dfSQL = pd.read_sql("SELECT * FROM Accela.dbo.v_LandCapabilityVerifications", conn)

# specify sde connection file
sdeBase = "C:\\GIS\\DB_CONNECT\\Vector.sde"

# create spatial dataframe from parcels in sde
parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Base"
sdfParcels = pd.DataFrame.spatial.from_featureclass(parcels)

# merge parcels and sql table on APN
df = pd.merge(sdfParcels, dfSQL, left_on='APN', right_on='GIS_ID', how='inner')

# rename some of the fields
df.rename(columns={"LABEL_FIELD": "Status"}, inplace=True)

# specify fields to keep
dfOut = df[["APN", "Status", "SHAPE"]].copy()

# delete output fc if exists
if arcpy.Exists(outFC):
    arcpy.Delete_management(outFC)

# spaital dataframe to feature class
dfOut.spatial.to_featureclass(outFC)

# confirm feature class was created
print("\nUpdated " + outFC)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print("\nTime it took to run this script: {}".format(endTimer))

# -------------------------------------------------------------- #

# start timer
startTimer = datetime.now()

# name of feature class
name = "Parcel_LCV_Challenge"
# specify output feature class
outFC = '//Arcprod/C$/GISData/PermitReview_AppData.gdb/' + name
# outFC = "C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb\\" + name

# make sql database connection with pyodbc
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};SERVER=ASQL;DATABASE=Accela;UID=BMP_Update;PWD=BMP_update_123')

# create dataframe from sql query
dfSQL = pd.read_sql("SELECT * FROM Accela.dbo.v_LandCapabilityChallenges", conn)

# specify sde connection file
sdeBase = "F:\\GIS\\GIS_DATA\\Vector.sde"

# create spatial dataframe from parcels in sde
parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Base"
sdfParcels = pd.DataFrame.spatial.from_featureclass(parcels)

# merge parcels and sql table on APN
df = pd.merge(sdfParcels, dfSQL, left_on='APN', right_on='GIS_ID', how='inner')

# rename some of the fields
df.rename(columns={"REC_DATE": "Date", "LABEL_FIELD": "Status"}, inplace=True)

# specify fields to keep
dfOut = df[["APN", "Date", "Status", "SHAPE"]].copy()

# delete output fc if exists
if arcpy.Exists(outFC):
    arcpy.Delete_management(outFC)

# spaital dataframe to feature class
dfOut.spatial.to_featureclass(outFC)

# confirm feature class was created
print("\nUpdated " + outFC)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print("\nTime it took to run this script: {}".format(endTimer))

# --------------------------------------------------------------- #

# start timer
startTimer = datetime.now()

# name of feature class
name = "Parcel_SoilsHydro"
# specify output feature class
outFC = '//Arcprod/C$/GISData/PermitReview_AppData.gdb/' + name
# outFC = "C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb\\" + name

# make sql database connection with pyodbc
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};SERVER=ASQL;DATABASE=Accela;UID=BMP_Update;PWD=BMP_update_123')

# create dataframe from sql query
dfSQL = pd.read_sql("SELECT * FROM Accela.dbo.v_HydroSoilsProjects", conn)

# specify sde connection file
sdeBase = "F:\\GIS\\GIS_DATA\\Vector.sde"

# create spatial dataframe from parcels in sde
parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Base"
sdfParcels = pd.DataFrame.spatial.from_featureclass(parcels)

# merge parcels and sql table on APN
df = pd.merge(sdfParcels, dfSQL, left_on='APN', right_on='GIS_ID', how='inner')

# rename some of the fields
df.rename(columns={"REC_DATE": "Date", "LABEL_FIELD": "Status"}, inplace=True)

# specify fields to keep
dfOut = df[["APN", "Date", "Status", "SHAPE"]].copy()

# delete output fc if exists
if arcpy.Exists(outFC):
    arcpy.Delete_management(outFC)

# spaital dataframe to feature class
dfOut.spatial.to_featureclass(outFC)

# confirm feature class was created
print("\nUpdated " + outFC)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print("\nTime it took to run this script: {}".format(endTimer))

# %% [markdown]
# # SDE to SDE

# %% [markdown]
# ## Parcel Edit to Parcel Master Staging

# %%
# import modules
import arcpy
import os

# overwrite outputs to true
arcpy.env.overwriteOutput = True

# in memory output file path
wk_memory = "in_memory" + "\\"

# network path to connection files
filePath = "C:\\GIS\\DBConnections"

# database file path 
sdeBase = os.path.join(filePath, "Vector.sde")
sdeCollectSDE = os.path.join(filePath, "Collection_SDE.sde")
sdeCollectBMP = os.path.join(filePath, "Collection_BMP.sde")
bmpDB = os.path.join(filePath, "BMP.sde")

# BMP Land use table
bmpLU =  bmpDB + "\\tahoebmpsde.dbo.v_BMPStatus"

# parcel feature classes to get updated
parcelMaster = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcel_Master"
parcelSimple = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Simplified"

# feature dataset path
landuseFD = "sde_collection.SDE.LandUse"

# feature dataset variable using db owner credentials to unregister and register versions
featureDataset = os.path.join(sdeCollectSDE, landuseFD)

# path to feature class using "BMP_UPDATE" db credentials
parcelCollect = os.path.join(sdeCollectBMP, landuseFD, "sde_collection.SDE.Parcel_Collection")

# function to transfer data
def fieldJoinCalc(updateFC, updateFieldsList, sourceFC, sourceFieldsList, sqlWhere):
    from time import strftime  
    print ("Started data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))
    # Use list comprehension to build a dictionary from a da SearchCursor  
    valueDict = {r[0]:(r[1:]) for r in arcpy.da.SearchCursor(sourceFC, sourceFieldsList, where_clause = sqlWhere)}  
    print ("transfering...")
    with arcpy.da.UpdateCursor(updateFC, updateFieldsList) as updateRows:  
        for updateRow in updateRows:  
            # store the Join value of the row being updated in a keyValue variable  
            keyValue = updateRow[0]  
            # verify that the keyValue is in the Dictionary  
            if keyValue in valueDict:  
                # transfer the value stored under the keyValue from the dictionary to the updated field.  
                updateRow[1] = valueDict[keyValue][0]  
                updateRows.updateRow(updateRow)    
    del valueDict  
    print ("Finished data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))

# start an edit session to apply changes to Parcel Master
edit = arcpy.da.Editor(sdeCollectSDE)
print ("edit created")
try:
    # unregister feature dataset as versioned using SDE credentials
    arcpy.UnregisterAsVersioned_management(featureDataset,"NO_KEEP_EDIT","COMPRESS_DEFAULT")
    print("feature dataset unregistered")
    # start an edit session
    edit.startEditing()
    print("edit started")
    edit.startOperation()
    print("operation started")
    # Perform edits
    ## transfer bmp land use values to parcel collect
    fieldJoinCalc(parcelCollect, ['APN', 'TRPA_LANDUSE_DESCRIPTION'], bmpLU, ['APN', 'LANDUSE'], "BMPStatus = 'BMP'")
    print("The 'TRPA_LANDUSE_DESCRIPTION' field in the parcel collection data has been updated")
    # stop edits
    edit.stopOperation()
    print("operation stopped")
    edit.stopEditing(True)  ## Stop the edit session with True to save the changes
    print("edit stopped")
    # register feature dataset as versioned using SDE credentials
    arcpy.RegisterAsVersioned_management(featureDataset, "EDITS_TO_BASE")
except Exception as err:
    print(err)
    if edit.isEditing:
        edit.stopOperation()
        print("operation stopped in except")
        edit.stopEditing(False)  ## Stop the edit session with False to abandon the changes
        print("edit stopped in except")
finally:
    # Cleanup
    arcpy.ClearWorkspaceCache_management()

# %% [markdown]
# ## Parcel Update to Parcel Edit

# %%
# import modules
import arcpy
import os

# overwrite outputs to true
arcpy.env.overwriteOutput = True

# in memory output file path
wk_memory = "in_memory" + "\\"

# network path to connection files
filePath = "C:\\GIS\\DBConnections"

# database file path 
sdeBase = os.path.join(filePath, "Vector.sde")
sdeCollectSDE = os.path.join(filePath, "Collection_SDE.sde")
sdeCollectBMP = os.path.join(filePath, "Collection_BMP.sde")
bmpDB = os.path.join(filePath, "BMP.sde")

# BMP Land use table
bmpLU =  bmpDB + "\\tahoebmpsde.dbo.v_BMPStatus"

# parcel feature classes to get updated
parcelMaster = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcel_Master"
parcelSimple = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Simplified"

# feature dataset path
landuseFD = "sde_collection.SDE.LandUse"

# feature dataset variable using db owner credentials to unregister and register versions
featureDataset = os.path.join(sdeCollectSDE, landuseFD)

# path to feature class using "BMP_UPDATE" db credentials
parcelCollect = os.path.join(sdeCollectBMP, landuseFD, "sde_collection.SDE.Parcel_Collection")

# function to transfer data
def fieldJoinCalc(updateFC, updateFieldsList, sourceFC, sourceFieldsList, sqlWhere):
    from time import strftime  
    print ("Started data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))
    # Use list comprehension to build a dictionary from a da SearchCursor  
    valueDict = {r[0]:(r[1:]) for r in arcpy.da.SearchCursor(sourceFC, sourceFieldsList, where_clause = sqlWhere)}  
    print ("transfering...")
    with arcpy.da.UpdateCursor(updateFC, updateFieldsList) as updateRows:  
        for updateRow in updateRows:  
            # store the Join value of the row being updated in a keyValue variable  
            keyValue = updateRow[0]  
            # verify that the keyValue is in the Dictionary  
            if keyValue in valueDict:  
                # transfer the value stored under the keyValue from the dictionary to the updated field.  
                updateRow[1] = valueDict[keyValue][0]  
                updateRows.updateRow(updateRow)    
    del valueDict  
    print ("Finished data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))

# start an edit session to apply changes to Parcel Master
edit = arcpy.da.Editor(sdeCollectSDE)
print ("edit created")
try:
    # unregister feature dataset as versioned using SDE credentials
    arcpy.UnregisterAsVersioned_management(featureDataset,"NO_KEEP_EDIT","COMPRESS_DEFAULT")
    print("feature dataset unregistered")
    # start an edit session
    edit.startEditing()
    print("edit started")
    edit.startOperation()
    print("operation started")
    # Perform edits
    ## transfer bmp land use values to parcel collect
    fieldJoinCalc(parcelCollect, ['APN', 'TRPA_LANDUSE_DESCRIPTION'], bmpLU, ['APN', 'LANDUSE'], "BMPStatus = 'BMP'")
    print("The 'TRPA_LANDUSE_DESCRIPTION' field in the parcel collection data has been updated")
    # stop edits
    edit.stopOperation()
    print("operation stopped")
    edit.stopEditing(True)  ## Stop the edit session with True to save the changes
    print("edit stopped")
    # register feature dataset as versioned using SDE credentials
    arcpy.RegisterAsVersioned_management(featureDataset, "EDITS_TO_BASE")
except Exception as err:
    print(err)
    if edit.isEditing:
        edit.stopOperation()
        print("operation stopped in except")
        edit.stopEditing(False)  ## Stop the edit session with False to abandon the changes
        print("edit stopped in except")
finally:
    # Cleanup
    arcpy.ClearWorkspaceCache_management()

# %% [markdown]
# ## Parcel Edit to Parcel Master

# %% [markdown]
# ### Move Recent Land Use Edits to TRPA Land Use Field in Parcel Master

# %%
# import modules
import arcpy
import os

# overwrite outputs to true
arcpy.env.overwriteOutput = True

# in memory output file path
wk_memory = "in_memory" + "\\"

# network path to connection files
filePath = "C:\\GIS\\DBConnections"

# database file path 
sdeBase = os.path.join(filePath, "Vector.sde")
sdeCollectSDE = os.path.join(filePath, "Collection_SDE.sde")
sdeCollectBMP = os.path.join(filePath, "Collection_BMP.sde")
bmpDB = os.path.join(filePath, "BMP.sde")

# BMP Land use table
bmpLU =  bmpDB + "\\tahoebmpsde.dbo.v_BMPStatus"

# parcel feature classes to get updated
parcelMaster = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcel_Master"
parcelSimple = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Simplified"

# feature dataset path
landuseFD = "sde_collection.SDE.LandUse"

# feature dataset variable using db owner credentials to unregister and register versions
featureDataset = os.path.join(sdeCollectSDE, landuseFD)

# path to feature class using "BMP_UPDATE" db credentials
parcelCollect = os.path.join(sdeCollectBMP, landuseFD, "sde_collection.SDE.Parcel_Collection")

# function to transfer data
def fieldJoinCalc(updateFC, updateFieldsList, sourceFC, sourceFieldsList, sqlWhere):
    from time import strftime  
    print ("Started data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))
    # Use list comprehension to build a dictionary from a da SearchCursor  
    valueDict = {r[0]:(r[1:]) for r in arcpy.da.SearchCursor(sourceFC, sourceFieldsList, where_clause = sqlWhere)}  
    print ("transfering...")
    with arcpy.da.UpdateCursor(updateFC, updateFieldsList) as updateRows:  
        for updateRow in updateRows:  
            # store the Join value of the row being updated in a keyValue variable  
            keyValue = updateRow[0]  
            # verify that the keyValue is in the Dictionary  
            if keyValue in valueDict:  
                # transfer the value stored under the keyValue from the dictionary to the updated field.  
                updateRow[1] = valueDict[keyValue][0]  
                updateRows.updateRow(updateRow)    
    del valueDict  
    print ("Finished data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))

# start an edit session to apply changes to Parcel Master
edit = arcpy.da.Editor(sdeCollectSDE)
print ("edit created")
try:
    # unregister feature dataset as versioned using SDE credentials
    arcpy.UnregisterAsVersioned_management(featureDataset,"NO_KEEP_EDIT","COMPRESS_DEFAULT")
    print("feature dataset unregistered")
    # start an edit session
    edit.startEditing()
    print("edit started")
    edit.startOperation()
    print("operation started")
    # Perform edits
    ## transfer bmp land use values to parcel collect
    fieldJoinCalc(parcelCollect, ['APN', 'TRPA_LANDUSE_DESCRIPTION'], bmpLU, ['APN', 'LANDUSE'], "BMPStatus = 'BMP'")
    print("The 'TRPA_LANDUSE_DESCRIPTION' field in the parcel collection data has been updated")
    # stop edits
    edit.stopOperation()
    print("operation stopped")
    edit.stopEditing(True)  ## Stop the edit session with True to save the changes
    print("edit stopped")
    # register feature dataset as versioned using SDE credentials
    arcpy.RegisterAsVersioned_management(featureDataset, "EDITS_TO_BASE")
except Exception as err:
    print(err)
    if edit.isEditing:
        edit.stopOperation()
        print("operation stopped in except")
        edit.stopEditing(False)  ## Stop the edit session with False to abandon the changes
        print("edit stopped in except")
finally:
    # Cleanup
    arcpy.ClearWorkspaceCache_management()

# %% [markdown]
# ## BMP Database to Parcel Edit

# %% [markdown]
# ### BMP Updated Land Use values to Parcel Edit Land Use

# %%
# in memory output file path
wk_memory = "in_memory" + "\\"

# network path to connection files
filePath = "C:\\GIS\\DBConnections"

# database file path 
sdeBase = os.path.join(filePath, "Vector.sde")
sdeCollectSDE = os.path.join(filePath, "Collection_SDE.sde")
sdeCollectBMP = os.path.join(filePath, "Collection_BMP.sde")
bmpDB = os.path.join(filePath, "BMP.sde")

# BMP Land use table
bmpLU =  bmpDB + "\\tahoebmpsde.dbo.v_BMPStatus"

# parcel feature classes to get updated
parcelMaster = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcel_Master"
parcelSimple = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Simplified"

# feature dataset path
fd = "sde_collection.SDE.Parcel"

# feature dataset variable using db owner credentials to unregister and register versions
featureDataset = os.path.join(sdeCollectSDE, fd)

# path to feature class using "BMP_UPDATE" db credentials
parcelCollect = os.path.join(sdeCollectBMP, landuseFD, "sde_collection.SDE.Parcel_Collection")

# function to transfer data
def fieldJoinCalc(updateFC, updateFieldsList, sourceFC, sourceFieldsList, sqlWhere):
    from time import strftime  
    print ("Started data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))
    # Use list comprehension to build a dictionary from a da SearchCursor  
    valueDict = {r[0]:(r[1:]) for r in arcpy.da.SearchCursor(sourceFC, sourceFieldsList, where_clause = sqlWhere)}  
    print ("transfering...")
    with arcpy.da.UpdateCursor(updateFC, updateFieldsList) as updateRows:  
        for updateRow in updateRows:  
            # store the Join value of the row being updated in a keyValue variable  
            keyValue = updateRow[0]  
            # verify that the keyValue is in the Dictionary  
            if keyValue in valueDict:  
                # transfer the value stored under the keyValue from the dictionary to the updated field.  
                updateRow[1] = valueDict[keyValue][0]  
                updateRows.updateRow(updateRow)    
    del valueDict  
    print ("Finished data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))

# start an edit session to apply changes to Parcel Master
edit = arcpy.da.Editor(sdeCollectSDE)
print ("edit created")

try:
    # unregister feature dataset as versioned using SDE credentials
    arcpy.UnregisterAsVersioned_management(featureDataset,"NO_KEEP_EDIT","COMPRESS_DEFAULT")
    print("feature dataset unregistered")
    # start an edit session
    edit.startEditing()
    print("edit started")
    edit.startOperation()
    print("operation started")
    # Perform edits
    ## transfer bmp land use values to parcel collect
    fieldJoinCalc(parcelCollect, ['APN', 'TRPA_LANDUSE_DESCRIPTION'], bmpLU, ['APN', 'LANDUSE'], "BMPStatus = 'BMP'")
    print("The 'TRPA_LANDUSE_DESCRIPTION' field in the parcel collection data has been updated")
    # stop edits
    edit.stopOperation()
    print("operation stopped")
    edit.stopEditing(True)  ## Stop the edit session with True to save the changes
    print("edit stopped")
    # register feature dataset as versioned using SDE credentials
    arcpy.RegisterAsVersioned_management(featureDataset, "EDITS_TO_BASE")
except Exception as err:
    print(err)
    if edit.isEditing:
        edit.stopOperation()
        print("operation stopped in except")
        edit.stopEditing(False)  ## Stop the edit session with False to abandon the changes
        print("edit stopped in except")
finally:
    # Cleanup
    arcpy.ClearWorkspaceCache_management()

# %% [markdown]
# ## Production Script

# %%
"""
BMP_LandUse_To_ParcelCollect.py
March 13th, 2020
Mason Bindl, Tahoe Regional Planning Agency

This python script was developed to extract verified land use
values from the BMP database, transfer them to the Parcel_Collect
feature class in Collection SDE, then transfer all the land use values
from that dataset to Parcel_Master in Production SDE.

This script uses Python 3.x and was designed to be used with 
the default ArcGIS Pro python enivorment "arcgispro-py3", with
no need for installing new libraries.

"""
# import modules
import arcpy
import os

# overwrite outputs to true
arcpy.env.overwriteOutput = True

# in memory output file path
wk_memory = "in_memory" + "\\"

# network path to connection files
filePath = "C:\\GIS\\DBConnections"

# database file path 
sdeBase = os.path.join(filePath, "Vector.sde")
sdeCollectSDE = os.path.join(filePath, "Collection_SDE.sde")
sdeCollectBMP = os.path.join(filePath, "Collection_BMP.sde")
bmpDB = os.path.join(filePath, "BMP.sde")

# BMP Land use table
bmpLU =  bmpDB + "\\tahoebmpsde.dbo.v_BMPStatus"

# parcel feature classes to get updated
parcelMaster = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcel_Master"
parcelSimple = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Simplified"

# feature dataset path
fd = "sde_collection.SDE.Parcel"

# feature dataset variable using db owner credentials to unregister and register versions
featureDataset = os.path.join(sdeCollectSDE, fd)

# path to feature class using "BMP_UPDATE" db credentials
parcelCollect = os.path.join(sdeCollectBMP, landuseFD, "sde_collection.SDE.Parcel_Collection")

# function to transfer data
def fieldJoinCalc(updateFC, updateFieldsList, sourceFC, sourceFieldsList, sqlWhere):
    from time import strftime  
    print ("Started data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))
    # Use list comprehension to build a dictionary from a da SearchCursor  
    valueDict = {r[0]:(r[1:]) for r in arcpy.da.SearchCursor(sourceFC, sourceFieldsList, where_clause = sqlWhere)}  
    print ("transfering...")
    with arcpy.da.UpdateCursor(updateFC, updateFieldsList) as updateRows:  
        for updateRow in updateRows:  
            # store the Join value of the row being updated in a keyValue variable  
            keyValue = updateRow[0]  
            # verify that the keyValue is in the Dictionary  
            if keyValue in valueDict:  
                # transfer the value stored under the keyValue from the dictionary to the updated field.  
                updateRow[1] = valueDict[keyValue][0]  
                updateRows.updateRow(updateRow)    
    del valueDict  
    print ("Finished data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))

# start an edit session to apply changes to Parcel Master
edit = arcpy.da.Editor(sdeCollectSDE)
print ("edit created")

try:
    # unregister feature dataset as versioned using SDE credentials
    arcpy.UnregisterAsVersioned_management(featureDataset,"NO_KEEP_EDIT","COMPRESS_DEFAULT")
    print("feature dataset unregistered")
    # start an edit session
    edit.startEditing()
    print("edit started")
    edit.startOperation()
    print("operation started")
    # Perform edits
    ## transfer bmp land use values to parcel collect
    fieldJoinCalc(parcelCollect, ['APN', 'TRPA_LANDUSE_DESCRIPTION'], bmpLU, ['APN', 'LANDUSE'], "BMPStatus = 'BMP'")
    print("The 'TRPA_LANDUSE_DESCRIPTION' field in the parcel collection data has been updated")
    # stop edits
    edit.stopOperation()
    print("operation stopped")
    edit.stopEditing(True)  ## Stop the edit session with True to save the changes
    print("edit stopped")
    # register feature dataset as versioned using SDE credentials
    arcpy.RegisterAsVersioned_management(featureDataset, "EDITS_TO_BASE")
except Exception as err:
    print(err)
    if edit.isEditing:
        edit.stopOperation()
        print("operation stopped in except")
        edit.stopEditing(False)  ## Stop the edit session with False to abandon the changes
        print("edit stopped in except")
finally:
    # Cleanup
    arcpy.ClearWorkspaceCache_management()

# %% [markdown]
# # LTinfo to SDE

# %% [markdown]
# ## LTInfo

# %%
# filter for active parcels
dfLTInfo_merge = dfLTAPN[(dfLTAPN.Status == "Active")]

# list of data frames to merge
data_frames = [dfLTInfo_merge, sdfParcels]

# merge dataframes
df = reduce(lambda  left,right: pd.merge(left,right,on=['APN'],
                                            how='left'), data_frames)
# export merged data frame to staging workspace
df.spatial.to_featureclass(location= workspace + "\Parcel_LTInfo")
# Out:
# 'C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb\\Parcel_LTInfo'

# %%
# start timer
startTimer = datetime.now()

# # copy parcel master to local gdb
# # parcel base
# parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Base"
# # copy
# arcpy.FeatureClassToFeatureClass_conversion(parcels, workspace,"ParcelsBase")

# # create spatial dataframe from parcel feature class
# sdfParcels = pd.DataFrame.spatial.from_featureclass('ParcelsBase')
# sdfParcels.info()


# # load pickle from dataframe
# with open(os.path.join(dfDump , "dfIPES.pickle"), 'rb') as f:
#     dfIPES = pickle.load(f)

dfIPES     = pd.read_json("https://laketahoeinfo.org/WebServices/GetParcelIPESScores/JSON/e17aeb86-85e3-4260-83fd-a2b32501c476")

# print data frame 
dfIPES.info()

# filter for active and official
dfIPES_merge = dfIPES[(dfIPES.Status == "Active") 
                            & (dfIPES.IPESScoreType == "Official")]

data_frames = [dfIPES_merge, sdfParcels]

# merge dataframes
df = reduce(lambda  left,right: pd.merge(left,right,on=['APN'], how='left'), data_frames)

# print dataframe info
df.info()

# export merged data frame to staging workspace
df.spatial.to_featureclass(location= workspace + "\Parcel_IPES")

# input fc
inputFC = "Parcel_IPES"

print("Imported arcpy, os, csv, and datatime modules.\n")
print(arcpy.ProductInfo())
## Set the Local Variables
#------------------------------------------------------------------------------------------------------#
# Change this to the path of your input feature class
inputfc = "Parcel_IPES"

# Change this to the path of your output FC
outfc = sdeCollect + "\\sde_collection.SDE.Parcel\\sde_collection.SDE.Parcel_LTinfo_IPES"

# feature dataset to unversion and register as version
fdata = sdeCollect + "\\sde_collection.SDE.Parcel"

fieldnames =  ['APN','PPNO','Status','ParcelNickname','IPESScore','IPESScoreType',
               'BaseAllowableCoveragePercent', 'IPESTotalAllowableCoverageSqFt',
               'ParcelHasDOAC', 'HistoricOrImportedIpesScore', 'CalculationDate',
               'FieldEvaluationDate', 'RelativeErosionHazardScore', 'RunoffPotentialScore',
               'AccessScore', 'UtilityInSEZScore', 'ConditionOfWatershedScore',
               'AbilityToRevegetateScore', 'WaterQualityImprovementsScore',
               'ProximityToLakeScore', 'LimitedIncentivePoints','TotalParcelArea',
               'IPESBuildingSiteArea', 'SEZLandArea','SEZSetbackArea','InternalNotes',
               'PublicNotes','PARCEL_ACRES', 'PARCEL_SQFT', 'SHAPE@']

#--------------------------------------------------------------------------------------------------------#

# disconnect all users
print("\nDisconnecting all users...")
arcpy.DisconnectUser(sdeCollect, "ALL")

print ("Unregistering feature dataset as versioned...")
# unregister the sde feature class as versioned
arcpy.UnregisterAsVersioned_management(fdata,"NO_KEEP_EDIT","COMPRESS_DEFAULT")
print ("Finished unregistering feature dataset as versioned.")
# set overwrite files envrionment setting to True
arcpy.env.overwriteOutput = True

# deletes all rows from the SDE feature class
arcpy.TruncateTable_management(outfc)
print ("\nDeleted all records in: {}\n".format(outfc))

# insert rows from Temporary feature class to SDE feature class
with arcpy.da.InsertCursor(outfc, fieldnames) as oCursor:
    count = 0
    with arcpy.da.SearchCursor(inputfc, fieldnames) as iCursor:
        for row in iCursor:
            oCursor.insertRow(row)
            count += 1
            if count % 1000 == 0:
                print("Inserting record {0} into SDE feature class".format(count))
# disconnect all users
print("\nDisconnecting all users...")
arcpy.DisconnectUser(sdeCollect, "ALL")

print("\nRegistering feature dataset as versioned...")
# register SDE feature class as versioned
arcpy.RegisterAsVersioned_management(fdata, "NO_EDITS_TO_BASE")
print("\nFinished registering feature dataset as versioned.")

# confirm feature class was created
print("\nUpdated " + outfc)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print ("\nTime it took to run this script: {}".format(endTimer))

# %% [markdown]
# ## LCV

# %%
dfLCV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21999 entries, 0 to 21998
# Data columns (total 30 columns):
# APN                    21999 non-null object
# Status                 21999 non-null object
# ParcelNickname         158 non-null object
# TotalAreaSqFt          21419 non-null float64
# UpdatedBy              21999 non-null object
# UpdatedOn              21999 non-null object
# DeterminationDate      21999 non-null object
# EstimatedOrVerified    21999 non-null object
# SitePlanUrl            21999 non-null object
# AccelaCAPRecord        5906 non-null object
# Bailey1aPresent        21999 non-null object
# Bailey1aSqFt           510 non-null float64
# Bailey1bPresent        21999 non-null object
# Bailey1bSqFt           970 non-null float64
# Bailey1cPresent        21999 non-null object
# Bailey1cSqFt           51 non-null float64
# Bailey2Present         21999 non-null object
# Bailey2SqFt            267 non-null float64
# Bailey3Present         21999 non-null object
# Bailey3SqFt            278 non-null float64
# Bailey4Present         21999 non-null object
# Bailey4SqFt            746 non-null float64
# Bailey5Present         21999 non-null object
# Bailey5SqFt            658 non-null float64
# Bailey6Present         21999 non-null object
# Bailey6SqFt            879 non-null float64
# Bailey7Present         21999 non-null object
# Bailey7SqFt            438 non-null float64
# IPESPresent            21999 non-null object
# IPESSqFt               9593 non-null float64
# dtypes: float64(11), object(19)
# memory usage: 5.0+ MB

# %%
# select fields
dfCoverageAllowed = dfLCV[['APN','Bailey1aSqFt', 'Bailey1bSqFt', 'Bailey1cSqFt','Bailey2SqFt','Bailey3SqFt','Bailey4SqFt', 'Bailey5SqFt', 'Bailey6SqFt', 'Bailey7SqFt','TotalAreaSqFt', 'Status', 'EstimatedOrVerified']]

# add coverage allowed field
dfCoverageAllowed["Developable_Area"] = np.nan

# calculate coverage allowed
dfCoverageAllowed['Developable_Area'] = dfCoverageAllowed[dfCoverageAllowed.columns[:-4]].sum(axis=1)

LCVquery = dfCoverageAllowed[(dfCoverageAllowed.Status == "Active") 
                            & (dfCoverageAllowed.EstimatedOrVerified == "Verified") 
                            & (dfCoverageAllowed.Developable_Area > 0)]

dfLCV_merge = LCVquery[['APN', 
                      'Developable_Area',
                      'TotalAreaSqFt', 
                      'Status', 
                      'EstimatedOrVerified']]

# list of dataframes to merge
data_frames = [dfLCV_merge, sdfParcels]

# merge dataframes
df = reduce(lambda  left,right: pd.merge(left,right,on=['APN'],
                                            how='left'), data_frames)
# export merged data frame to staging workspace
df.spatial.to_featureclass(location= workspace + "\Parcel_LCV")
# Out:
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 'C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb\\Parcel_LCV'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3109 entries, 0 to 3108
# Data columns (total 11 columns):
# APN                    3109 non-null object
# Developable_Area       3109 non-null float64
# TotalAreaSqFt          3109 non-null float64
# Status                 3109 non-null object
# EstimatedOrVerified    3109 non-null object
# OBJECTID               3109 non-null int64
# PPNO                   3109 non-null float64
# PARCEL_ACRES           3109 non-null float64
# PARCEL_SQFT            3109 non-null float64
# JURISDICTION           3109 non-null object
# SHAPE                  3109 non-null geometry
# dtypes: float64(5), geometry(1), int64(1), object(4)
# memory usage: 267.3+ KB

# %%
# start timer
startTimer = datetime.now()

# # copy parcel master to local gdb
# # parcel base
# parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Base"
# # copy
# arcpy.FeatureClassToFeatureClass_conversion(parcels, workspace,"ParcelsBase")

# # create spatial dataframe from parcel feature class
# sdfParcels = pd.DataFrame.spatial.from_featureclass('ParcelsBase')
# sdfParcels.info()


# # load pickle from dataframe
# with open(os.path.join(dfDump , "dfIPES.pickle"), 'rb') as f:
#     dfIPES = pickle.load(f)

dfIPES     = pd.read_json("https://laketahoeinfo.org/WebServices/GetParcelIPESScores/JSON/e17aeb86-85e3-4260-83fd-a2b32501c476")

# print data frame 
dfIPES.info()

# filter for active and official
dfIPES_merge = dfIPES[(dfIPES.Status == "Active") 
                            & (dfIPES.IPESScoreType == "Official")]

data_frames = [dfIPES_merge, sdfParcels]

# merge dataframes
df = reduce(lambda  left,right: pd.merge(left,right,on=['APN'], how='left'), data_frames)

# print dataframe info
df.info()

# export merged data frame to staging workspace
df.spatial.to_featureclass(location= workspace + "\Parcel_IPES")

# input fc
inputFC = "Parcel_IPES"

print("Imported arcpy, os, csv, and datatime modules.\n")
print(arcpy.ProductInfo())
## Set the Local Variables
#------------------------------------------------------------------------------------------------------#
# Change this to the path of your input feature class
inputfc = "Parcel_IPES"

# Change this to the path of your output FC
outfc = sdeCollect + "\\sde_collection.SDE.Parcel\\sde_collection.SDE.Parcel_LTinfo_IPES"

# feature dataset to unversion and register as version
fdata = sdeCollect + "\\sde_collection.SDE.Parcel"

fieldnames =  ['APN','PPNO','Status','ParcelNickname','IPESScore','IPESScoreType',
               'BaseAllowableCoveragePercent', 'IPESTotalAllowableCoverageSqFt',
               'ParcelHasDOAC', 'HistoricOrImportedIpesScore', 'CalculationDate',
               'FieldEvaluationDate', 'RelativeErosionHazardScore', 'RunoffPotentialScore',
               'AccessScore', 'UtilityInSEZScore', 'ConditionOfWatershedScore',
               'AbilityToRevegetateScore', 'WaterQualityImprovementsScore',
               'ProximityToLakeScore', 'LimitedIncentivePoints','TotalParcelArea',
               'IPESBuildingSiteArea', 'SEZLandArea','SEZSetbackArea','InternalNotes',
               'PublicNotes','PARCEL_ACRES', 'PARCEL_SQFT', 'SHAPE@']

#--------------------------------------------------------------------------------------------------------#

# disconnect all users
print("\nDisconnecting all users...")
arcpy.DisconnectUser(sdeCollect, "ALL")

print ("Unregistering feature dataset as versioned...")
# unregister the sde feature class as versioned
arcpy.UnregisterAsVersioned_management(fdata,"NO_KEEP_EDIT","COMPRESS_DEFAULT")
print ("Finished unregistering feature dataset as versioned.")
# set overwrite files envrionment setting to True
arcpy.env.overwriteOutput = True

# deletes all rows from the SDE feature class
arcpy.TruncateTable_management(outfc)
print ("\nDeleted all records in: {}\n".format(outfc))

# insert rows from Temporary feature class to SDE feature class
with arcpy.da.InsertCursor(outfc, fieldnames) as oCursor:
    count = 0
    with arcpy.da.SearchCursor(inputfc, fieldnames) as iCursor:
        for row in iCursor:
            oCursor.insertRow(row)
            count += 1
            if count % 1000 == 0:
                print("Inserting record {0} into SDE feature class".format(count))
# disconnect all users
print("\nDisconnecting all users...")
arcpy.DisconnectUser(sdeCollect, "ALL")

print("\nRegistering feature dataset as versioned...")
# register SDE feature class as versioned
arcpy.RegisterAsVersioned_management(fdata, "NO_EDITS_TO_BASE")
print("\nFinished registering feature dataset as versioned.")

# confirm feature class was created
print("\nUpdated " + outfc)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print ("\nTime it took to run this script: {}".format(endTimer))

# %% [markdown]
# ## IPES

# %%
# start timer
startTimer = datetime.now()

# # copy parcel master to local gdb
# # parcel base
# parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Base"
# # copy
# arcpy.FeatureClassToFeatureClass_conversion(parcels, workspace,"ParcelsBase")

# # create spatial dataframe from parcel feature class
# sdfParcels = pd.DataFrame.spatial.from_featureclass('ParcelsBase')
# sdfParcels.info()


# # load pickle from dataframe
# with open(os.path.join(dfDump , "dfIPES.pickle"), 'rb') as f:
#     dfIPES = pickle.load(f)

dfIPES     = pd.read_json("https://laketahoeinfo.org/WebServices/GetParcelIPESScores/JSON/e17aeb86-85e3-4260-83fd-a2b32501c476")

# print data frame 
dfIPES.info()

# filter for active and official
dfIPES_merge = dfIPES[(dfIPES.Status == "Active") 
                            & (dfIPES.IPESScoreType == "Official")]

data_frames = [dfIPES_merge, sdfParcels]

# merge dataframes
df = reduce(lambda  left,right: pd.merge(left,right,on=['APN'], how='left'), data_frames)

# print dataframe info
df.info()

# export merged data frame to staging workspace
df.spatial.to_featureclass(location= workspace + "\Parcel_IPES")

print("Imported arcpy, os, csv, and datatime modules.\n")
print(arcpy.ProductInfo())
## Set the Local Variables
#------------------------------------------------------------------------------------------------------#
# Change this to the path of your input feature class
inputfc = "Parcel_IPES"

# Change this to the path of your output FC
outfc = sdeCollect + "\\sde_collection.SDE.Parcel\\sde_collection.SDE.Parcel_LTinfo_IPES"

# feature dataset to unversion and register as version
fdata = sdeCollect + "\\sde_collection.SDE.Parcel"

fieldnames =  ['APN','PPNO','Status','ParcelNickname','IPESScore','IPESScoreType',
               'BaseAllowableCoveragePercent', 'IPESTotalAllowableCoverageSqFt',
               'ParcelHasDOAC', 'HistoricOrImportedIpesScore', 'CalculationDate',
               'FieldEvaluationDate', 'RelativeErosionHazardScore', 'RunoffPotentialScore',
               'AccessScore', 'UtilityInSEZScore', 'ConditionOfWatershedScore',
               'AbilityToRevegetateScore', 'WaterQualityImprovementsScore',
               'ProximityToLakeScore', 'LimitedIncentivePoints','TotalParcelArea',
               'IPESBuildingSiteArea', 'SEZLandArea','SEZSetbackArea','InternalNotes',
               'PublicNotes','PARCEL_ACRES', 'PARCEL_SQFT', 'SHAPE@']

#--------------------------------------------------------------------------------------------------------#

# disconnect all users
print("\nDisconnecting all users...")
arcpy.DisconnectUser(sdeCollect, "ALL")

print ("Unregistering feature dataset as versioned...")
# unregister the sde feature class as versioned
arcpy.UnregisterAsVersioned_management(fdata,"NO_KEEP_EDIT","COMPRESS_DEFAULT")
print ("Finished unregistering feature dataset as versioned.")
# set overwrite files envrionment setting to True
arcpy.env.overwriteOutput = True

# deletes all rows from the SDE feature class
arcpy.TruncateTable_management(outfc)
print ("\nDeleted all records in: {}\n".format(outfc))

# insert rows from Temporary feature class to SDE feature class
with arcpy.da.InsertCursor(outfc, fieldnames) as oCursor:
    count = 0
    with arcpy.da.SearchCursor(inputfc, fieldnames) as iCursor:
        for row in iCursor:
            oCursor.insertRow(row)
            count += 1
            if count % 1000 == 0:
                print("Inserting record {0} into SDE feature class".format(count))
# disconnect all users
print("\nDisconnecting all users...")
arcpy.DisconnectUser(sdeCollect, "ALL")

print("\nRegistering feature dataset as versioned...")
# register SDE feature class as versioned
arcpy.RegisterAsVersioned_management(fdata, "NO_EDITS_TO_BASE")
print("\nFinished registering feature dataset as versioned.")

# confirm feature class was created
print("\nUpdated " + outfc)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print ("\nTime it took to run this script: {}".format(endTimer))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14651 entries, 0 to 14650
# Data columns (total 27 columns):
# ScoreSheetUrl                     14651 non-null object
# APN                               14651 non-null object
# Status                            14651 non-null object
# ParcelNickname                    14651 non-null object
# IPESScore                         14649 non-null float64
# IPESScoreType                     14651 non-null object
# BaseAllowableCoveragePercent      14651 non-null object
# IPESTotalAllowableCoverageSqFt    861 non-null float64
# ParcelHasDOAC                     14651 non-null object
# HistoricOrImportedIpesScore       14651 non-null object
# CalculationDate                   14651 non-null object
# FieldEvaluationDate               14651 non-null object
# RelativeErosionHazardScore        14470 non-null float64
# RunoffPotentialScore              14470 non-null float64
# AccessScore                       14470 non-null float64
# UtilityInSEZScore                 14470 non-null float64
# ConditionOfWatershedScore         14470 non-null float64
# AbilityToRevegetateScore          14470 non-null float64
# WaterQualityImprovementsScore     14487 non-null float64
# ProximityToLakeScore              14470 non-null float64
# LimitedIncentivePoints            14481 non-null float64
# TotalParcelArea                   145 non-null float64
# IPESBuildingSiteArea              13645 non-null float64
# SEZLandArea                       14484 non-null float64
# SEZSetbackArea                    14481 non-null float64
# InternalNotes                     14651 non-null object
# PublicNotes                       14651 non-null object
# dtypes: float64(15), object(12)
# memory usage: 3.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10909 entries, 0 to 10908
# Data columns (total 33 columns):
# ScoreSheetUrl                     10909 non-null object
# APN                               10909 non-null object
# Status                            10909 non-null object
# ParcelNickname                    10909 non-null object
# IPESScore                         10909 non-null float64
# IPESScoreType                     10909 non-null object
# BaseAllowableCoveragePercent      10909 non-null object
# IPESTotalAllowableCoverageSqFt    581 non-null float64
# ParcelHasDOAC                     10909 non-null object
# HistoricOrImportedIpesScore       10909 non-null object
# CalculationDate                   10909 non-null object
# FieldEvaluationDate               10909 non-null object
# RelativeErosionHazardScore        10774 non-null float64
# RunoffPotentialScore              10774 non-null float64
# AccessScore                       10774 non-null float64
# UtilityInSEZScore                 10774 non-null float64
# ConditionOfWatershedScore         10774 non-null float64
# AbilityToRevegetateScore          10774 non-null float64
# WaterQualityImprovementsScore     10774 non-null float64
# ProximityToLakeScore              10774 non-null float64
# LimitedIncentivePoints            10771 non-null float64
# TotalParcelArea                   101 non-null float64
# IPESBuildingSiteArea              9963 non-null float64
# SEZLandArea                       10774 non-null float64
# SEZSetbackArea                    10773 non-null float64
# InternalNotes                     10909 non-null object
# PublicNotes                       10909 non-null object
# OBJECTID                          10909 non-null int64
# PPNO                              10909 non-null float64
# PARCEL_ACRES                      10909 non-null float64
# PARCEL_SQFT                       10909 non-null float64
# JURISDICTION                      10909 non-null object
# SHAPE                             10909 non-null object
# dtypes: float64(18), int64(1), object(14)
# memory usage: 2.8+ MB
# Imported arcpy, os, csv, and datatime modules.
#
# ArcInfo
#
# Disconnecting all users...
# Unregistering feature dataset as versioned...
# Finished unregistering feature dataset as versioned.
#
# Deleted all records in: C:\GIS\DB_CONNECT\Collection.sde\sde_collection.SDE.Parcel\sde_collection.SDE.Parcel_LTinfo_IPES
#
# Inserting record 1000 into SDE feature class
# Inserting record 2000 into SDE feature class
# Inserting record 3000 into SDE feature class
# Inserting record 4000 into SDE feature class
# Inserting record 5000 into SDE feature class
# Inserting record 6000 into SDE feature class
# Inserting record 7000 into SDE feature class
# Inserting record 8000 into SDE feature class
# Inserting record 9000 into SDE feature class
# Inserting record 10000 into SDE feature class
#
# Disconnecting all users...
#
# Registering feature dataset as versioned...
#
# Finished registering feature dataset as versioned.
#
# Updated C:\GIS\DB_CONNECT\Collection.sde\sde_collection.SDE.Parcel\sde_collection.SDE.Parcel_LTinfo_IPES
#
# Time it took to run this script: 0:04:40.726607

# %% [markdown]
# ## Development Right

# %%
# list of dataframes to merge
data_frames = [dfDevBank, sdfParcels]

# merge dataframes
df = reduce(lambda  left,right: pd.merge(left,right,on=['APN'],
                                            how='left'), data_frames)
# export merged data frame to staging workspace
df.spatial.to_featureclass(location= workspace + "\Parcel_DevelopmentRight")
# Out:
# 'C:\\GIS\\PROJECT\\ScratchPaper\\ScratchPaper.gdb\\Parcel_DevelopmentRight'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1593 entries, 0 to 1592
# Data columns (total 17 columns):
# APN                     1593 non-null object
# DevelopmentRight        1593 non-null object
# LandCapability          1593 non-null object
# IPESScore               401 non-null float64
# BankedQuanitity         1593 non-null int64
# CurrentInventory        1593 non-null int64
# Jurisdiction            1593 non-null object
# LocalPlan               1573 non-null object
# DateBankedOrApproved    1593 non-null object
# HRA                     1591 non-null object
# LastUpdated             1593 non-null object
# OBJECTID                1523 non-null float64
# PPNO                    1523 non-null float64
# PARCEL_ACRES            1523 non-null float64
# PARCEL_SQFT             1523 non-null float64
# JURISDICTION            1523 non-null object
# SHAPE                   1523 non-null geometry
# dtypes: float64(5), geometry(1), int64(2), object(9)
# memory usage: 211.7+ KB

# %%
# start timer
startTimer = datetime.now()

# # copy parcel master to local gdb
# # parcel base
# parcels = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Base"
# # copy
# arcpy.FeatureClassToFeatureClass_conversion(parcels, workspace,"ParcelsBase")

# # create spatial dataframe from parcel feature class
# sdfParcels = pd.DataFrame.spatial.from_featureclass('ParcelsBase')
# sdfParcels.info()


# # load pickle from dataframe
# with open(os.path.join(dfDump , "dfIPES.pickle"), 'rb') as f:
#     dfIPES = pickle.load(f)

dfIPES     = pd.read_json("https://laketahoeinfo.org/WebServices/GetParcelIPESScores/JSON/e17aeb86-85e3-4260-83fd-a2b32501c476")

# print data frame 
dfIPES.info()

# filter for active and official
dfIPES_merge = dfIPES[(dfIPES.Status == "Active") 
                            & (dfIPES.IPESScoreType == "Official")]

data_frames = [dfIPES_merge, sdfParcels]

# merge dataframes
df = reduce(lambda  left,right: pd.merge(left,right,on=['APN'], how='left'), data_frames)

# print dataframe info
df.info()

# export merged data frame to staging workspace
df.spatial.to_featureclass(location= workspace + "\Parcel_IPES")

# input fc
inputFC = "Parcel_IPES"

print("Imported arcpy, os, csv, and datatime modules.\n")
print(arcpy.ProductInfo())
## Set the Local Variables
#------------------------------------------------------------------------------------------------------#
# Change this to the path of your input feature class
inputfc = "Parcel_IPES"

# Change this to the path of your output FC
outfc = sdeCollect + "\\sde_collection.SDE.Parcel\\sde_collection.SDE.Parcel_LTinfo_IPES"

# feature dataset to unversion and register as version
fdata = sdeCollect + "\\sde_collection.SDE.Parcel"

fieldnames =  ['APN','PPNO','Status','ParcelNickname','IPESScore','IPESScoreType',
               'BaseAllowableCoveragePercent', 'IPESTotalAllowableCoverageSqFt',
               'ParcelHasDOAC', 'HistoricOrImportedIpesScore', 'CalculationDate',
               'FieldEvaluationDate', 'RelativeErosionHazardScore', 'RunoffPotentialScore',
               'AccessScore', 'UtilityInSEZScore', 'ConditionOfWatershedScore',
               'AbilityToRevegetateScore', 'WaterQualityImprovementsScore',
               'ProximityToLakeScore', 'LimitedIncentivePoints','TotalParcelArea',
               'IPESBuildingSiteArea', 'SEZLandArea','SEZSetbackArea','InternalNotes',
               'PublicNotes','PARCEL_ACRES', 'PARCEL_SQFT', 'SHAPE@']

#--------------------------------------------------------------------------------------------------------#

# disconnect all users
print("\nDisconnecting all users...")
arcpy.DisconnectUser(sdeCollect, "ALL")

print ("Unregistering feature dataset as versioned...")
# unregister the sde feature class as versioned
arcpy.UnregisterAsVersioned_management(fdata,"NO_KEEP_EDIT","COMPRESS_DEFAULT")
print ("Finished unregistering feature dataset as versioned.")
# set overwrite files envrionment setting to True
arcpy.env.overwriteOutput = True

# deletes all rows from the SDE feature class
arcpy.TruncateTable_management(outfc)
print ("\nDeleted all records in: {}\n".format(outfc))

# insert rows from Temporary feature class to SDE feature class
with arcpy.da.InsertCursor(outfc, fieldnames) as oCursor:
    count = 0
    with arcpy.da.SearchCursor(inputfc, fieldnames) as iCursor:
        for row in iCursor:
            oCursor.insertRow(row)
            count += 1
            if count % 1000 == 0:
                print("Inserting record {0} into SDE feature class".format(count))
# disconnect all users
print("\nDisconnecting all users...")
arcpy.DisconnectUser(sdeCollect, "ALL")

print("\nRegistering feature dataset as versioned...")
# register SDE feature class as versioned
arcpy.RegisterAsVersioned_management(fdata, "NO_EDITS_TO_BASE")
print("\nFinished registering feature dataset as versioned.")

# confirm feature class was created
print("\nUpdated " + outfc)

# report how long it took to run the script
endTimer = datetime.now() - startTimer
print ("\nTime it took to run this script: {}".format(endTimer))

# %%
# in memory output file path
wk_memory = "in_memory" + "\\"

# network path to connection files
filePath = "C:\\GIS\\DBConnections"

# database file path 
sdeBase = os.path.join(filePath, "Vector.sde")
sdeCollectSDE = os.path.join(filePath, "Collection_SDE.sde")
sdeCollectBMP = os.path.join(filePath, "Collection_BMP.sde")
bmpDB = os.path.join(filePath, "BMP.sde")

# BMP Land use table
bmpLU =  bmpDB + "\\tahoebmpsde.dbo.v_BMPStatus"

# parcel feature classes to get updated
parcelMaster = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcel_Master"
parcelSimple = sdeBase + "\\sde.SDE.Parcels\\sde.SDE.Parcels_Simplified"

# feature dataset path
landuseFD = "sde_collection.SDE.LandUse"

# feature dataset variable using db owner credentials to unregister and register versions
featureDataset = os.path.join(sdeCollectSDE, landuseFD)

# path to feature class using "BMP_UPDATE" db credentials
parcelCollect = os.path.join(sdeCollectBMP, landuseFD, "sde_collection.SDE.Parcel_Collection")

# function to transfer data
def fieldJoinCalc(updateFC, updateFieldsList, sourceFC, sourceFieldsList, sqlWhere):
    from time import strftime  
    print ("Started data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))
    # Use list comprehension to build a dictionary from a da SearchCursor  
    valueDict = {r[0]:(r[1:]) for r in arcpy.da.SearchCursor(sourceFC, sourceFieldsList, where_clause = sqlWhere)}  
    print ("transfering...")
    with arcpy.da.UpdateCursor(updateFC, updateFieldsList) as updateRows:  
        for updateRow in updateRows:  
            # store the Join value of the row being updated in a keyValue variable  
            keyValue = updateRow[0]  
            # verify that the keyValue is in the Dictionary  
            if keyValue in valueDict:  
                # transfer the value stored under the keyValue from the dictionary to the updated field.  
                updateRow[1] = valueDict[keyValue][0]  
                updateRows.updateRow(updateRow)    
    del valueDict  
    print ("Finished data transfer: " + strftime("%Y-%m-%d %H:%M:%S"))

# start an edit session to apply changes to Parcel Master
edit = arcpy.da.Editor(sdeCollectSDE)
print ("edit created")

try:
    # unregister feature dataset as versioned using SDE credentials
    arcpy.UnregisterAsVersioned_management(featureDataset,"NO_KEEP_EDIT","COMPRESS_DEFAULT")
    print("feature dataset unregistered")
    # start an edit session
    edit.startEditing()
    print("edit started")
    edit.startOperation()
    print("operation started")
    # Perform edits
    ## transfer bmp land use values to parcel collect
    fieldJoinCalc(parcelCollect, ['APN', 'TRPA_LANDUSE_DESCRIPTION'], bmpLU, ['APN', 'LANDUSE'], "BMPStatus = 'BMP'")
    print("The 'TRPA_LANDUSE_DESCRIPTION' field in the parcel collection data has been updated")
    # stop edits
    edit.stopOperation()
    print("operation stopped")
    edit.stopEditing(True)  ## Stop the edit session with True to save the changes
    print("edit stopped")
    # register feature dataset as versioned using SDE credentials
    arcpy.RegisterAsVersioned_management(featureDataset, "EDITS_TO_BASE")
except Exception as err:
    print(err)
    if edit.isEditing:
        edit.stopOperation()
        print("operation stopped in except")
        edit.stopEditing(False)  ## Stop the edit session with False to abandon the changes
        print("edit stopped in except")
finally:
    # Cleanup
    arcpy.ClearWorkspaceCache_management()

# %% [markdown]
# # Identify Old APNs

# %% [markdown]
# ## Parcel Tracker

# %%
# merge parcel_master and ipes
dfLTInfo = pd.merge(sdfParcels, dfLTAPN, on='APN', how='outer')
df = dfLTInfo[(dfLTInfo.OBJECTID.isnull())]
dfNull = df[['APN', 'Status']]
dfNull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9697 entries, 61263 to 70959
# Data columns (total 2 columns):
# APN       9697 non-null object
# Status    9697 non-null object
# dtypes: object(2)
# memory usage: 227.3+ KB

# %%
# merge parcel_master and ipes
dfLTInfo = pd.merge(sdfParcels, dfLTAPN, on='APN', how='outer')
df = dfLTInfo[(dfLTInfo.OBJECTID.isnull()) & (dfLTInfo.Status == 'Inactive')]
dfNull = df[['APN', 'Status']]
dfNull
# Out:
#               APN    Status
# 61263  001-010-02  Inactive
# 61264  001-010-03  Inactive
# 61265  001-010-04  Inactive
# 61266  001-010-05  Inactive
# 61267  001-010-07  Inactive
# 61268  001-010-11  Inactive
# 61269  001-010-13  Inactive
# 61270  001-020-01  Inactive
# 61271  001-020-02  Inactive
# 61272  001-020-03  Inactive
# 61273  001-020-04  Inactive
# 61274  001-020-05  Inactive
# 61275  001-020-07  Inactive
# 61276  001-020-08  Inactive
# 61277  001-020-09  Inactive
# 61278  001-020-14  Inactive
# 61279  001-020-15  Inactive
# 61280  001-020-16  Inactive
# 61281  001-020-20  Inactive
# 61282  001-020-23  Inactive
# 61283  001-020-24  Inactive
# 61284  001-030-01  Inactive
# 61285  001-030-02  Inactive
# 61286  001-030-03  Inactive
# 61287  001-030-04  Inactive
# 61288  001-030-06  Inactive
# 61289  001-030-07  Inactive
# 61290  001-030-08  Inactive
# 61291  001-030-12  Inactive
# 61292  001-030-14  Inactive
# ...           ...       ...
# 70930  991-385-13  Inactive
# 70931  991-385-14  Inactive
# 70932  991-385-15  Inactive
# 70933  991-385-45  Inactive
# 70934  991-385-46  Inactive
# 70935  991-385-47  Inactive
# 70936  991-385-48  Inactive
# 70937  991-385-62  Inactive
# 70938  991-385-63  Inactive
# 70939  991-386-19  Inactive
# 70940  991-386-20  Inactive
# 70941  991-386-21  Inactive
# 70942  991-386-22  Inactive
# 70943  991-386-23  Inactive
# 70944  991-386-24  Inactive
# 70945  991-386-25  Inactive
# 70946  991-386-26  Inactive
# 70947  991-386-27  Inactive
# 70948  991-386-87  Inactive
# 70949  991-386-88  Inactive
# 70950  991-386-89  Inactive
# 70951  991-386-97  Inactive
# 70952  991-386-98  Inactive
# 70953  991-386-99  Inactive
# 70954  991-387-00  Inactive
# 70955  991-387-01  Inactive
# 70956  991-387-02  Inactive
# 70957  999-888-77  Inactive
# 70958  999-99-999  Inactive
# 70959  999-999-99  Inactive
#
# [9648 rows x 2 columns]

# %% [markdown]
# ## LCV

# %%
# merge parcel_master and ipes
dfLCVNULL = pd.merge(sdfParcels, dfLCV, on='APN', how='outer')
df = dfLCVNULL[(dfLCVNULL.OBJECTID.isnull() & (dfLCVNULL.Status == 'Inactive'))]
dfNull = df[['APN', 'Status']]
dfNull
# Out:
#                    APN    Status
# 61263       001-050-09  Inactive
# 61264       005-113-04  Inactive
# 61265       005-113-05  Inactive
# 61266       005-331-08  Inactive
# 61267       014-274-10  Inactive
# 61268       014-274-11  Inactive
# 61269       014-274-12  Inactive
# 61270       014-291-02  Inactive
# 61271       014-360-09  Inactive
# 61272       015-103-27  Inactive
# 61273       015-162-08  Inactive
# 61274       015-162-18  Inactive
# 61275       015-201-20  Inactive
# 61276       015-201-21  Inactive
# 61277       015-213-25  Inactive
# 61278       015-303-31  Inactive
# 61279       015-314-24  Inactive
# 61280       015-370-22  Inactive
# 61281       015-370-23  Inactive
# 61282       016-051-06  Inactive
# 61283       016-091-42  Inactive
# 61284       016-091-50  Inactive
# 61285       016-091-52  Inactive
# 61286       016-101-14  Inactive
# 61287       016-120-11  Inactive
# 61288       016-202-11  Inactive
# 61289       016-211-14  Inactive
# 61290       016-300-59  Inactive
# 61291       016-410-10  Inactive
# 61292       016-544-14  Inactive
# ...                ...       ...
# 62198  1318-25-110-011  Inactive
# 62199  1318-26-501-002  Inactive
# 62200  1318-26-501-003  Inactive
# 62201  1318-27-001-012  Inactive
# 62202  1319-18-401-001  Inactive
# 62203  1319-18-410-013  Inactive
# 62204  1319-19-212-014  Inactive
# 62205       132-020-04  Inactive
# 62206       132-020-24  Inactive
# 62207       132-201-01  Inactive
# 62208       132-223-09  Inactive
# 62209       132-232-02  Inactive
# 62210       132-232-10  Inactive
# 62211       132-232-12  Inactive
# 62212  1418-00-002-007  Inactive
# 62213  1418-10-501-001  Inactive
# 62214  1418-10-702-006  Inactive
# 62215  1418-10-702-007  Inactive
# 62216  1418-10-802-008  Inactive
# 62217  1418-27-210-029  Inactive
# 62218  1418-27-210-030  Inactive
# 62219  1418-34-101-001  Inactive
# 62220  1418-34-110-039  Inactive
# 62221  1418-34-210-007  Inactive
# 62222  1418-34-211-026  Inactive
# 62223  1418-34-401-009  Inactive
# 62224  1418-34-401-010  Inactive
# 62225  1418-34-401-011  Inactive
# 62226  1418-34-601-002  Inactive
# 62227  1418-34-601-005  Inactive
#
# [951 rows x 2 columns]

# %%
dfLCVNULL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62229 entries, 0 to 62228
# Data columns (total 90 columns):
# OBJECTID                          61263 non-null float64
# APN                               62229 non-null object
# PPNO                              61263 non-null float64
# HSE_NUMBR                         61263 non-null float64
# UNIT_NUMBR                        61263 non-null object
# STR_DIR                           61263 non-null object
# STR_NAME                          61263 non-null object
# STR_SUFFIX                        61263 non-null object
# APO_ADDRESS                       61263 non-null object
# PSTL_TOWN                         61263 non-null object
# PSTL_STATE                        61263 non-null object
# PSTL_ZIP5                         61263 non-null object
# OWN_FIRST                         61263 non-null object
# OWN_LAST                          61263 non-null object
# OWN_FULL                          61263 non-null object
# MAIL_ADD1                         61263 non-null object
# MAIL_ADD2                         61263 non-null object
# MAIL_CITY                         61263 non-null object
# MAIL_STATE                        61263 non-null object
# MAIL_ZIP5                         61263 non-null object
# JURISDICTION                      61263 non-null object
# COUNTY                            61263 non-null object
# OWNERSHIP_TYPE                    61263 non-null object
# COUNTY_LANDUSE_CODE               61263 non-null object
# COUNTY_LANDUSE_DESCRIPTION        61263 non-null object
# TRPA_LANDUSE_DESCRIPTION          61263 non-null object
# REGIONAL_LANDUSE                  61263 non-null object
# UNITS                             61263 non-null object
# BEDROOMS                          61263 non-null object
# BATHROOMS                         61263 non-null object
# ALLOWABLE_COVERAGE_BAILEY_SQFT    61256 non-null float64
# IMPERVIOUS_SURFACE_SQFT           61263 non-null float64
# SOIL_1974                         61263 non-null object
# SOIL_2003                         61263 non-null object
# HRA_NAME                          61263 non-null object
# WATERSHED_NUMBER                  61263 non-null float64
# WATERSHED_NAME                    61263 non-null object
# PRIORITY_WATERSHED                61263 non-null object
# FIREPD                            61263 non-null object
# WITHIN_TRPA_BNDY                  61263 non-null float64
# LITTORAL                          61263 non-null float64
# AS_LANDVALUE                      61263 non-null float64
# AS_IMPROVALUE                     61263 non-null float64
# AS_SUM                            61263 non-null float64
# TAX_LANDVALUE                     61263 non-null float64
# TAX_IMPROVALUE                    61263 non-null float64
# TAX_SUM                           61263 non-null float64
# TAX_YEAR                          61263 non-null object
# PLAN_ID                           61263 non-null object
# PLAN_NAME                         61263 non-null object
# ZONING_ID                         61263 non-null object
# ZONING_DESCRIPTION                61263 non-null object
# TOWN_CENTER                       61263 non-null object
# LOCATION_TO_TOWNCENTER            61263 non-null object
# INDEX_1987                        61263 non-null object
# LOCAL_PLAN_HYPERLINK              61263 non-null object
# DESIGN_GUIDELINES_HYPERLINK       61263 non-null object
# INDEX_1987_HYPERLINK              61263 non-null object
# PARCEL_ACRES                      61263 non-null float64
# PARCEL_SQFT                       61263 non-null float64
# SHAPE                             61263 non-null object
# AccelaCAPRecord                   5477 non-null object
# Bailey1aPresent                   21483 non-null object
# Bailey1aSqFt                      503 non-null float64
# Bailey1bPresent                   21483 non-null object
# Bailey1bSqFt                      945 non-null float64
# Bailey1cPresent                   21483 non-null object
# Bailey1cSqFt                      51 non-null float64
# Bailey2Present                    21483 non-null object
# Bailey2SqFt                       244 non-null float64
# Bailey3Present                    21483 non-null object
# Bailey3SqFt                       271 non-null float64
# Bailey4Present                    21483 non-null object
# Bailey4SqFt                       719 non-null float64
# Bailey5Present                    21483 non-null object
# Bailey5SqFt                       646 non-null float64
# Bailey6Present                    21483 non-null object
# Bailey6SqFt                       860 non-null float64
# Bailey7Present                    21483 non-null object
# Bailey7SqFt                       426 non-null float64
# DeterminationDate                 21483 non-null object
# EstimatedOrVerified               21483 non-null object
# IPESPresent                       21483 non-null object
# IPESSqFt                          9601 non-null float64
# ParcelNickname                    141 non-null object
# SitePlanUrl                       21483 non-null object
# Status                            21483 non-null object
# TotalAreaSqFt                     20900 non-null float64
# UpdatedBy                         21483 non-null object
# UpdatedOn                         21483 non-null object
# dtypes: float64(27), object(63)
# memory usage: 43.2+ MB

# %%
dfLCVNULL
# Out:
#        OBJECTID              APN        PPNO  HSE_NUMBR UNIT_NUMBR STR_DIR  \
# 0           4.0       048-042-03   4804203.0        0.0
# 1           5.0       048-140-01   4814001.0        0.0
# 2           6.0       048-140-02   4814002.0        0.0
# 3           7.0       048-140-03   4814003.0        0.0
# 4           8.0       048-140-04   4814004.0        0.0
# 5           9.0       055-010-07   5501007.0        0.0
# 6          10.0       055-010-08   5501008.0        0.0
# 7          14.0       055-010-26   5501026.0        0.0
# 8          15.0       122-051-01  12205101.0      643.0
# 9          16.0       122-051-02  12205102.0      640.0
# 10         17.0       122-051-03  12205103.0      636.0
# 11         18.0       122-051-04  12205104.0      632.0
# 12         19.0       122-051-05  12205105.0      626.0
# 13         20.0       122-051-06  12205106.0      618.0
# 14         21.0       122-051-07  12205107.0      617.0
# 15         22.0       122-051-08  12205108.0      621.0
# 16         23.0       122-051-09  12205109.0      627.0
# 17         24.0       122-051-10  12205110.0      633.0
# 18         25.0       122-052-01  12205201.0        0.0
# 19         26.0       122-052-02  12205202.0      630.0
# 20         27.0       122-052-03  12205203.0      628.0
# 21         28.0       122-052-04  12205204.0      622.0
# 22         29.0       122-052-05  12205205.0      616.0
# 23         30.0       122-052-06  12205206.0        0.0
# 24         31.0       122-052-07  12205207.0      609.0
# 25         32.0       122-052-08  12205208.0      615.0
# 26         33.0       122-052-09  12205209.0      619.0
# 27         34.0       122-052-10  12205210.0      623.0
# 28         35.0       122-052-11  12205211.0      629.0
# 29         36.0       122-052-12  12205212.0      633.0
# ...         ...              ...         ...        ...        ...     ...
# 62199       NaN  1318-26-501-002         NaN        NaN        NaN     NaN
# 62200       NaN  1318-26-501-003         NaN        NaN        NaN     NaN
# 62201       NaN  1318-27-001-012         NaN        NaN        NaN     NaN
# 62202       NaN  1319-18-401-001         NaN        NaN        NaN     NaN
# 62203       NaN  1319-18-410-013         NaN        NaN        NaN     NaN
# 62204       NaN  1319-19-212-014         NaN        NaN        NaN     NaN
# 62205       NaN       132-020-04         NaN        NaN        NaN     NaN
# 62206       NaN       132-020-24         NaN        NaN        NaN     NaN
# 62207       NaN       132-201-01         NaN        NaN        NaN     NaN
# 62208       NaN       132-223-09         NaN        NaN        NaN     NaN
# 62209       NaN       132-232-02         NaN        NaN        NaN     NaN
# 62210       NaN       132-232-10         NaN        NaN        NaN     NaN
# 62211       NaN       132-232-12         NaN        NaN        NaN     NaN
# 62212       NaN  1418-00-002-007         NaN        NaN        NaN     NaN
# 62213       NaN  1418-10-501-001         NaN        NaN        NaN     NaN
# 62214       NaN  1418-10-702-006         NaN        NaN        NaN     NaN
# 62215       NaN  1418-10-702-007         NaN        NaN        NaN     NaN
# 62216       NaN  1418-10-802-008         NaN        NaN        NaN     NaN
# 62217       NaN  1418-27-210-029         NaN        NaN        NaN     NaN
# 62218       NaN  1418-27-210-030         NaN        NaN        NaN     NaN
# 62219       NaN  1418-34-101-001         NaN        NaN        NaN     NaN
# 62220       NaN  1418-34-110-039         NaN        NaN        NaN     NaN
# 62221       NaN  1418-34-210-007         NaN        NaN        NaN     NaN
# 62222       NaN  1418-34-211-026         NaN        NaN        NaN     NaN
# 62223       NaN  1418-34-401-009         NaN        NaN        NaN     NaN
# 62224       NaN  1418-34-401-010         NaN        NaN        NaN     NaN
# 62225       NaN  1418-34-401-011         NaN        NaN        NaN     NaN
# 62226       NaN  1418-34-601-002         NaN        NaN        NaN     NaN
# 62227       NaN  1418-34-601-005         NaN        NaN        NaN     NaN
# 62228       NaN       560-101-00         NaN        NaN        NaN     NaN
#
#                STR_NAME STR_SUFFIX         APO_ADDRESS        PSTL_TOWN  ...  \
# 0            MOUNT ROSE        HWY    0 MOUNT ROSE HWY                   ...
# 1            MOUNT ROSE        HWY    0 MOUNT ROSE HWY                   ...
# 2            MOUNT ROSE        HWY    0 MOUNT ROSE HWY                   ...
# 3            MOUNT ROSE        HWY    0 MOUNT ROSE HWY                   ...
# 4            MOUNT ROSE        HWY    0 MOUNT ROSE HWY                   ...
# 5      US HIGHWAY 395 S             0 US HIGHWAY 395 S                   ...
# 6      US HIGHWAY 395 S             0 US HIGHWAY 395 S                   ...
# 7      US HIGHWAY 395 S             0 US HIGHWAY 395 S                   ...
# 8             2ND CREEK         DR    643 2ND CREEK DR  Incline Village  ...
# 9             WOODRIDGE        CIR   640 WOODRIDGE CIR  Incline Village  ...
# 10            WOODRIDGE        CIR   636 WOODRIDGE CIR  Incline Village  ...
# 11            WOODRIDGE        CIR   632 WOODRIDGE CIR  Incline Village  ...
# 12            WOODRIDGE        CIR   626 WOODRIDGE CIR  Incline Village  ...
# 13            WOODRIDGE        CIR   618 WOODRIDGE CIR  Incline Village  ...
# 14            WOODRIDGE        CIR   617 WOODRIDGE CIR  Incline Village  ...
# 15            WOODRIDGE        CIR   621 WOODRIDGE CIR  Incline Village  ...
# 16            WOODRIDGE        CIR   627 WOODRIDGE CIR  Incline Village  ...
# 17            2ND CREEK         DR    633 2ND CREEK DR  Incline Village  ...
# 18            2ND CREEK         DR      0 2ND CREEK DR  Incline Village  ...
# 19            WOODRIDGE        CIR   630 WOODRIDGE CIR  Incline Village  ...
# 20            WOODRIDGE        CIR   628 WOODRIDGE CIR  Incline Village  ...
# 21            WOODRIDGE        CIR   622 WOODRIDGE CIR  Incline Village  ...
# 22            WOODRIDGE        CIR   616 WOODRIDGE CIR  Incline Village  ...
# 23                                                   0  Incline Village  ...
# 24            WOODRIDGE        CIR   609 WOODRIDGE CIR  Incline Village  ...
# 25            WOODRIDGE        CIR   615 WOODRIDGE CIR  Incline Village  ...
# 26            WOODRIDGE        CIR   619 WOODRIDGE CIR  Incline Village  ...
# 27            WOODRIDGE        CIR   623 WOODRIDGE CIR  Incline Village  ...
# 28            WOODRIDGE        CIR   629 WOODRIDGE CIR  Incline Village  ...
# 29            WOODRIDGE        CIR   633 WOODRIDGE CIR  Incline Village  ...
# ...                 ...        ...                 ...              ...  ...
# 62199               NaN        NaN                 NaN              NaN  ...
# 62200               NaN        NaN                 NaN              NaN  ...
# 62201               NaN        NaN                 NaN              NaN  ...
# 62202               NaN        NaN                 NaN              NaN  ...
# 62203               NaN        NaN                 NaN              NaN  ...
# 62204               NaN        NaN                 NaN              NaN  ...
# 62205               NaN        NaN                 NaN              NaN  ...
# 62206               NaN        NaN                 NaN              NaN  ...
# 62207               NaN        NaN                 NaN              NaN  ...
# 62208               NaN        NaN                 NaN              NaN  ...
# 62209               NaN        NaN                 NaN              NaN  ...
# 62210               NaN        NaN                 NaN              NaN  ...
# 62211               NaN        NaN                 NaN              NaN  ...
# 62212               NaN        NaN                 NaN              NaN  ...
# 62213               NaN        NaN                 NaN              NaN  ...
# 62214               NaN        NaN                 NaN              NaN  ...
# 62215               NaN        NaN                 NaN              NaN  ...
# 62216               NaN        NaN                 NaN              NaN  ...
# 62217               NaN        NaN                 NaN              NaN  ...
# 62218               NaN        NaN                 NaN              NaN  ...
# 62219               NaN        NaN                 NaN              NaN  ...
# 62220               NaN        NaN                 NaN              NaN  ...
# 62221               NaN        NaN                 NaN              NaN  ...
# 62222               NaN        NaN                 NaN              NaN  ...
# 62223               NaN        NaN                 NaN              NaN  ...
# 62224               NaN        NaN                 NaN              NaN  ...
# 62225               NaN        NaN                 NaN              NaN  ...
# 62226               NaN        NaN                 NaN              NaN  ...
# 62227               NaN        NaN                 NaN              NaN  ...
# 62228               NaN        NaN                 NaN              NaN  ...
#
#          DeterminationDate EstimatedOrVerified IPESPresent IPESSqFt  \
# 0      02/23/2006 12:00 AM            Verified          No      NaN
# 1                      NaN                 NaN         NaN      NaN
# 2                      NaN                 NaN         NaN      NaN
# 3      02/23/2006 12:00 AM            Verified          No      NaN
# 4      02/27/2006 12:00 AM            Verified          No      NaN
# 5                      NaN                 NaN         NaN      NaN
# 6                      NaN                 NaN         NaN      NaN
# 7                      NaN                 NaN         NaN      NaN
# 8      10/02/1989 12:00 AM            Verified          No      NaN
# 9      08/11/1992 12:00 AM            Verified          No      NaN
# 10     06/17/1997 12:00 AM            Verified          No      NaN
# 11     10/29/2002 12:00 AM            Verified          No      NaN
# 12     06/26/2004 12:00 AM            Verified          No      NaN
# 13                     NaN                 NaN         NaN      NaN
# 14                     NaN                 NaN         NaN      NaN
# 15                     NaN                 NaN         NaN      NaN
# 16                     NaN                 NaN         NaN      NaN
# 17                     NaN                 NaN         NaN      NaN
# 18      12/19/2016 4:38 PM            Verified         Yes  20900.0
# 19                     NaN                 NaN         NaN      NaN
# 20     05/20/1991 12:00 AM            Verified          No      NaN
# 21                     NaN                 NaN         NaN      NaN
# 22     12/04/2003 12:00 AM            Verified          No      NaN
# 23     05/25/1993 12:00 AM            Verified          No      NaN
# 24     08/27/2008 12:00 AM            Verified          No      NaN
# 25     05/21/2019 12:00 AM            Verified          No      NaN
# 26                     NaN                 NaN         NaN      NaN
# 27     10/05/1995 12:00 AM            Verified          No      NaN
# 28                     NaN                 NaN         NaN      NaN
# 29     05/24/2006 12:00 AM            Verified          No      NaN
# ...                    ...                 ...         ...      ...
# 62199  06/03/2004 12:00 AM            Verified          No      NaN
# 62200  06/03/3004 12:00 AM            Verified          No      NaN
# 62201  11/03/2011 12:00 AM            Verified          No      NaN
# 62202  11/17/2009 12:00 AM            Verified          No      NaN
# 62203  10/08/2009 12:00 AM            Verified          No      NaN
# 62204  04/11/2005 12:00 AM            Verified          No      NaN
# 62205  07/07/2016 12:00 AM            Verified          No      NaN
# 62206  07/07/2016 12:00 AM            Verified          No      NaN
# 62207  07/07/2016 12:00 AM            Verified          No      NaN
# 62208  07/07/2016 12:00 AM            Verified          No      NaN
# 62209  07/07/2016 12:00 AM            Verified          No      NaN
# 62210  07/07/2016 12:00 AM            Verified          No      NaN
# 62211  04/22/1999 12:00 AM            Verified          No      NaN
# 62212  09/04/1995 12:00 AM            Verified          No      NaN
# 62213  05/09/2011 12:00 AM            Verified          No      NaN
# 62214  03/10/2017 12:00 AM            Verified          No      NaN
# 62215  05/10/1999 12:00 AM            Verified          No      NaN
# 62216  01/19/2018 12:00 AM            Verified          No      NaN
# 62217  09/26/2013 12:00 AM            Verified          No      NaN
# 62218  02/26/2014 12:00 AM            Verified         Yes  15429.0
# 62219  06/10/1996 12:00 AM            Verified          No      NaN
# 62220  05/22/2006 12:00 AM            Verified          No      NaN
# 62221  02/22/2008 12:00 AM            Verified          No      NaN
# 62222  12/06/2012 12:00 AM            Verified          No      NaN
# 62223  01/06/2011 12:00 AM            Verified          No      NaN
# 62224  01/12/2011 12:00 AM            Verified          No      NaN
# 62225  01/12/2011 12:00 AM            Verified          No      NaN
# 62226  10/12/2006 12:00 AM            Verified          No      NaN
# 62227  12/11/2008 12:00 AM            Verified          No      NaN
# 62228  07/24/2019 12:00 AM           Estimated          No      NaN
#
#       ParcelNickname                                        SitePlanUrl  \
# 0               None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3               None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 4               None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 5                NaN                                                NaN
# 6                NaN                                                NaN
# 7                NaN                                                NaN
# 8               None                                               None
# 9               None                                               None
# 10              None                                               None
# 11              None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 12              None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 13               NaN                                                NaN
# 14               NaN                                                NaN
# 15               NaN                                                NaN
# 16               NaN                                                NaN
# 17               NaN                                                NaN
# 18              None                                               None
# 19               NaN                                                NaN
# 20              None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 21               NaN                                                NaN
# 22              None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 23              None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 24              None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 25              None                                               None
# 26               NaN                                                NaN
# 27              None                                               None
# 28               NaN                                                NaN
# 29              None  https://qa.laketahoeinfo.org/FileResource/Disp...
# ...              ...                                                ...
# 62199           None                                               None
# 62200           None                                               None
# 62201           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62202           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62203           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62204           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62205           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62206           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62207           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62208           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62209           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62210           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62211           None                                               None
# 62212           None                                               None
# 62213           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62214           None                                               None
# 62215           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62216           None                                               None
# 62217           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62218           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62219           None                                               None
# 62220           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62221           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62222           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62223           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62224           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62225           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62226           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62227           None  https://qa.laketahoeinfo.org/FileResource/Disp...
# 62228           None                                               None
#
#          Status TotalAreaSqFt           UpdatedBy            UpdatedOn
# 0        Active     4745879.0          Adele Gerz  08/09/2016 11:56 AM
# 1           NaN           NaN                 NaN                  NaN
# 2           NaN           NaN                 NaN                  NaN
# 3        Active      217843.0          Adele Gerz  08/09/2016 12:07 PM
# 4        Active    28126586.0          Adele Gerz  08/09/2016 12:20 PM
# 5           NaN           NaN                 NaN                  NaN
# 6           NaN           NaN                 NaN                  NaN
# 7           NaN           NaN                 NaN                  NaN
# 8        Active       28132.0         Sean Tevlin   06/30/2016 9:40 AM
# 9        Active       27868.0         Sean Tevlin   06/30/2016 9:41 AM
# 10       Active       21255.0         Sean Tevlin   06/30/2016 9:42 AM
# 11       Active       24338.0     Jeanne McNamara  11/16/2017 12:48 PM
# 12       Active       23168.0         Sean Tevlin   06/30/2016 9:46 AM
# 13          NaN           NaN                 NaN                  NaN
# 14          NaN           NaN                 NaN                  NaN
# 15          NaN           NaN                 NaN                  NaN
# 16          NaN           NaN                 NaN                  NaN
# 17          NaN           NaN                 NaN                  NaN
# 18       Active       22564.0          Ken Kasman   12/19/2016 4:38 PM
# 19          NaN           NaN                 NaN                  NaN
# 20       Active       26025.0         Sean Tevlin   06/30/2016 9:48 AM
# 21          NaN           NaN                 NaN                  NaN
# 22       Active       42042.0         Sean Tevlin   06/30/2016 9:50 AM
# 23       Active       54733.0         Sean Tevlin   06/30/2016 9:53 AM
# 24       Active       39475.0         Sean Tevlin   06/30/2016 9:58 AM
# 25       Active       50576.0          Alex Eidam  05/21/2019 11:52 AM
# 26          NaN           NaN                 NaN                  NaN
# 27       Active       21817.0         Sean Tevlin   06/30/2016 9:58 AM
# 28          NaN           NaN                 NaN                  NaN
# 29       Active       21103.0         Sean Tevlin  06/30/2016 10:01 AM
# ...         ...           ...                 ...                  ...
# 62199  Inactive           NaN     Jeanne McNamara   06/11/2019 4:51 PM
# 62200  Inactive           NaN     Jeanne McNamara   06/11/2019 4:53 PM
# 62201  Inactive      158295.0         Sean Tevlin   06/15/2016 2:44 PM
# 62202  Inactive     1752056.0         Sean Tevlin   06/15/2016 4:02 PM
# 62203  Inactive       15301.0         Sean Tevlin   06/15/2016 4:12 PM
# 62204  Inactive        2503.0         Sean Tevlin  06/20/2016 11:43 AM
# 62205  Inactive           NaN          Adele Gerz  07/07/2016 12:00 AM
# 62206  Inactive           NaN          Adele Gerz  07/07/2016 12:00 AM
# 62207  Inactive           NaN     Jeanne McNamara   06/02/2017 9:36 AM
# 62208  Inactive           NaN     Jeanne McNamara   06/02/2017 9:38 AM
# 62209  Inactive       35157.0     Jeanne McNamara   06/02/2017 9:40 AM
# 62210  Inactive           NaN     Jeanne McNamara   06/02/2017 9:41 AM
# 62211  Inactive       22653.0     Jeanne McNamara  08/03/2016 10:12 AM
# 62212  Inactive    13054017.0         Sean Tevlin  06/20/2016 12:32 PM
# 62213  Inactive       94603.0         Sean Tevlin   06/20/2016 1:49 PM
# 62214  Inactive       21246.0          Adele Gerz   03/10/2017 3:26 PM
# 62215  Inactive       50629.0          Adele Gerz  01/19/2018 12:07 PM
# 62216  Inactive      401743.0          Adele Gerz  01/19/2018 10:51 AM
# 62217  Inactive       43828.0         Sean Tevlin  06/23/2016 10:36 AM
# 62218  Inactive       15634.0          Adele Gerz   12/21/2016 9:21 AM
# 62219  Inactive      110284.0          Adele Gerz   09/27/2018 3:40 PM
# 62220  Inactive        7699.0         Sean Tevlin  06/23/2016 12:17 PM
# 62221  Inactive       20257.0  Laurie Hockenberry  04/11/2017 11:19 AM
# 62222  Inactive       10170.0         Sean Tevlin  06/23/2016 12:43 PM
# 62223  Inactive      120526.0  Laurie Hockenberry   03/12/2018 1:46 PM
# 62224  Inactive       12007.0  Laurie Hockenberry  07/09/2016 11:43 AM
# 62225  Inactive       12009.0          Adele Gerz   08/20/2016 9:23 AM
# 62226  Inactive       57379.0  Laurie Hockenberry  07/09/2016 12:45 PM
# 62227  Inactive       18748.0  Laurie Hockenberry   07/11/2016 4:01 PM
# 62228    Active     7448973.0     Jeanne McNamara  07/24/2019 11:01 AM
#
# [62229 rows x 90 columns]

# %% [markdown]
# ## IPES

# %%
# merge parcel_master and ipes
dfIPESNULL = pd.merge(sdfParcels, dfIPES, on='APN', how='outer')
df = dfIPESNULL[(dfIPESNULL.OBJECTID.isnull())]
dfNull = df[['APN', "JURISDICTION", 'IPESScore', 'Status']]
dfNull
# Out:
#                    APN JURISDICTION  IPESScore    Status
# 63192       001-010-05          NaN      815.0  Inactive
# 63193       001-010-07          NaN      673.0  Inactive
# 63194       001-010-07          NaN      718.0  Inactive
# 63195       001-020-03          NaN      699.0  Inactive
# 63196       001-020-03          NaN      650.0  Inactive
# 63197       001-020-16          NaN      725.0  Inactive
# 63198       001-030-08          NaN      851.0  Inactive
# 63199       001-030-19          NaN      791.0  Inactive
# 63200       001-030-22          NaN      652.0  Inactive
# 63201       001-040-02          NaN      880.0  Inactive
# 63202       001-050-09          NaN      839.0  Inactive
# 63203       001-050-25          NaN      755.0  Inactive
# 63204       001-060-14          NaN      990.0  Inactive
# 63205       001-080-02          NaN      571.0  Inactive
# 63206       001-080-18          NaN      784.0  Inactive
# 63207       001-080-19          NaN     1004.0  Inactive
# 63208       001-080-19          NaN      740.0  Inactive
# 63209       001-090-10          NaN      515.0  Inactive
# 63210       001-090-21          NaN      875.0  Inactive
# 63211       001-090-21          NaN      659.0  Inactive
# 63212       001-100-01          NaN      802.0  Inactive
# 63213       001-100-02          NaN      811.0  Inactive
# 63214       001-100-09          NaN      886.0  Inactive
# 63215       001-100-09          NaN      918.0  Inactive
# 63216       001-100-10          NaN      804.0  Inactive
# 63217       001-100-10          NaN      808.0  Inactive
# 63218       001-100-11          NaN      949.0  Inactive
# 63219       001-100-13          NaN      975.0  Inactive
# 63220       001-100-14          NaN      923.0  Inactive
# 63221       001-100-15          NaN      846.0  Inactive
# ...                ...          ...        ...       ...
# 64931       132-222-13          NaN      801.0  Inactive
# 64932       132-222-14          NaN      776.0  Inactive
# 64933       132-223-03          NaN      815.0  Inactive
# 64934       132-223-04          NaN      828.0  Inactive
# 64935       132-223-08          NaN      815.0  Inactive
# 64936       132-223-09          NaN      829.0  Inactive
# 64937  1418-11-311-005          NaN      714.0  Inactive
# 64938  1418-15-110-016          NaN      758.0  Inactive
# 64939  1418-15-110-018          NaN      694.0  Inactive
# 64940  1418-15-511-003          NaN      808.0  Inactive
# 64941  1418-15-511-003          NaN      804.0  Inactive
# 64942  1418-27-210-030          NaN      887.0  Inactive
# 64943  1418-27-210-031          NaN      873.0  Inactive
# 64944  1418-27-601-006          NaN      640.0  Inactive
# 64945  1418-27-601-006          NaN      658.0  Inactive
# 64946  1418-27-601-006          NaN      661.0  Inactive
# 64947  1418-27-601-006          NaN      617.0  Inactive
# 64948  1418-34-101-004          NaN      779.0  Inactive
# 64949  1418-34-101-007          NaN      671.0  Inactive
# 64950  1418-34-101-007          NaN      716.0  Inactive
# 64951  1418-34-101-008          NaN      756.0  Inactive
# 64952  1418-34-101-009          NaN      675.0  Inactive
# 64953  1418-34-101-010          NaN      816.0  Inactive
# 64954  1418-34-110-006          NaN      106.0  Inactive
# 64955  1418-34-110-024          NaN      750.0  Inactive
# 64956  1418-34-110-031          NaN      901.0  Inactive
# 64957  1418-34-110-031          NaN      871.0  Inactive
# 64958  1418-34-211-027          NaN      707.0  Inactive
# 64959  1418-34-211-027          NaN      694.0  Inactive
# 64960      177-100-083          NaN      636.0  Inactive
#
# [1769 rows x 4 columns]

# %%
dfIPESNULL
# Out:
#        OBJECTID              APN        PPNO  HSE_NUMBR UNIT_NUMBR STR_DIR  \
# 0           4.0       048-042-03   4804203.0        0.0
# 1           5.0       048-140-01   4814001.0        0.0
# 2           6.0       048-140-02   4814002.0        0.0
# 3           7.0       048-140-03   4814003.0        0.0
# 4           8.0       048-140-04   4814004.0        0.0
# 5           9.0       055-010-07   5501007.0        0.0
# 6          10.0       055-010-08   5501008.0        0.0
# 7          14.0       055-010-26   5501026.0        0.0
# 8          15.0       122-051-01  12205101.0      643.0
# 9          16.0       122-051-02  12205102.0      640.0
# 10         17.0       122-051-03  12205103.0      636.0
# 11         18.0       122-051-04  12205104.0      632.0
# 12         19.0       122-051-05  12205105.0      626.0
# 13         20.0       122-051-06  12205106.0      618.0
# 14         21.0       122-051-07  12205107.0      617.0
# 15         22.0       122-051-08  12205108.0      621.0
# 16         23.0       122-051-09  12205109.0      627.0
# 17         24.0       122-051-10  12205110.0      633.0
# 18         25.0       122-052-01  12205201.0        0.0
# 19         26.0       122-052-02  12205202.0      630.0
# 20         27.0       122-052-03  12205203.0      628.0
# 21         28.0       122-052-04  12205204.0      622.0
# 22         29.0       122-052-05  12205205.0      616.0
# 23         30.0       122-052-06  12205206.0        0.0
# 24         31.0       122-052-07  12205207.0      609.0
# 25         32.0       122-052-08  12205208.0      615.0
# 26         33.0       122-052-09  12205209.0      619.0
# 27         34.0       122-052-10  12205210.0      623.0
# 28         35.0       122-052-11  12205211.0      629.0
# 29         36.0       122-052-12  12205212.0      633.0
# ...         ...              ...         ...        ...        ...     ...
# 64931       NaN       132-222-13         NaN        NaN        NaN     NaN
# 64932       NaN       132-222-14         NaN        NaN        NaN     NaN
# 64933       NaN       132-223-03         NaN        NaN        NaN     NaN
# 64934       NaN       132-223-04         NaN        NaN        NaN     NaN
# 64935       NaN       132-223-08         NaN        NaN        NaN     NaN
# 64936       NaN       132-223-09         NaN        NaN        NaN     NaN
# 64937       NaN  1418-11-311-005         NaN        NaN        NaN     NaN
# 64938       NaN  1418-15-110-016         NaN        NaN        NaN     NaN
# 64939       NaN  1418-15-110-018         NaN        NaN        NaN     NaN
# 64940       NaN  1418-15-511-003         NaN        NaN        NaN     NaN
# 64941       NaN  1418-15-511-003         NaN        NaN        NaN     NaN
# 64942       NaN  1418-27-210-030         NaN        NaN        NaN     NaN
# 64943       NaN  1418-27-210-031         NaN        NaN        NaN     NaN
# 64944       NaN  1418-27-601-006         NaN        NaN        NaN     NaN
# 64945       NaN  1418-27-601-006         NaN        NaN        NaN     NaN
# 64946       NaN  1418-27-601-006         NaN        NaN        NaN     NaN
# 64947       NaN  1418-27-601-006         NaN        NaN        NaN     NaN
# 64948       NaN  1418-34-101-004         NaN        NaN        NaN     NaN
# 64949       NaN  1418-34-101-007         NaN        NaN        NaN     NaN
# 64950       NaN  1418-34-101-007         NaN        NaN        NaN     NaN
# 64951       NaN  1418-34-101-008         NaN        NaN        NaN     NaN
# 64952       NaN  1418-34-101-009         NaN        NaN        NaN     NaN
# 64953       NaN  1418-34-101-010         NaN        NaN        NaN     NaN
# 64954       NaN  1418-34-110-006         NaN        NaN        NaN     NaN
# 64955       NaN  1418-34-110-024         NaN        NaN        NaN     NaN
# 64956       NaN  1418-34-110-031         NaN        NaN        NaN     NaN
# 64957       NaN  1418-34-110-031         NaN        NaN        NaN     NaN
# 64958       NaN  1418-34-211-027         NaN        NaN        NaN     NaN
# 64959       NaN  1418-34-211-027         NaN        NaN        NaN     NaN
# 64960       NaN      177-100-083         NaN        NaN        NaN     NaN
#
#                STR_NAME STR_SUFFIX         APO_ADDRESS        PSTL_TOWN  ...  \
# 0            MOUNT ROSE        HWY    0 MOUNT ROSE HWY                   ...
# 1            MOUNT ROSE        HWY    0 MOUNT ROSE HWY                   ...
# 2            MOUNT ROSE        HWY    0 MOUNT ROSE HWY                   ...
# 3            MOUNT ROSE        HWY    0 MOUNT ROSE HWY                   ...
# 4            MOUNT ROSE        HWY    0 MOUNT ROSE HWY                   ...
# 5      US HIGHWAY 395 S             0 US HIGHWAY 395 S                   ...
# 6      US HIGHWAY 395 S             0 US HIGHWAY 395 S                   ...
# 7      US HIGHWAY 395 S             0 US HIGHWAY 395 S                   ...
# 8             2ND CREEK         DR    643 2ND CREEK DR  Incline Village  ...
# 9             WOODRIDGE        CIR   640 WOODRIDGE CIR  Incline Village  ...
# 10            WOODRIDGE        CIR   636 WOODRIDGE CIR  Incline Village  ...
# 11            WOODRIDGE        CIR   632 WOODRIDGE CIR  Incline Village  ...
# 12            WOODRIDGE        CIR   626 WOODRIDGE CIR  Incline Village  ...
# 13            WOODRIDGE        CIR   618 WOODRIDGE CIR  Incline Village  ...
# 14            WOODRIDGE        CIR   617 WOODRIDGE CIR  Incline Village  ...
# 15            WOODRIDGE        CIR   621 WOODRIDGE CIR  Incline Village  ...
# 16            WOODRIDGE        CIR   627 WOODRIDGE CIR  Incline Village  ...
# 17            2ND CREEK         DR    633 2ND CREEK DR  Incline Village  ...
# 18            2ND CREEK         DR      0 2ND CREEK DR  Incline Village  ...
# 19            WOODRIDGE        CIR   630 WOODRIDGE CIR  Incline Village  ...
# 20            WOODRIDGE        CIR   628 WOODRIDGE CIR  Incline Village  ...
# 21            WOODRIDGE        CIR   622 WOODRIDGE CIR  Incline Village  ...
# 22            WOODRIDGE        CIR   616 WOODRIDGE CIR  Incline Village  ...
# 23                                                   0  Incline Village  ...
# 24            WOODRIDGE        CIR   609 WOODRIDGE CIR  Incline Village  ...
# 25            WOODRIDGE        CIR   615 WOODRIDGE CIR  Incline Village  ...
# 26            WOODRIDGE        CIR   619 WOODRIDGE CIR  Incline Village  ...
# 27            WOODRIDGE        CIR   623 WOODRIDGE CIR  Incline Village  ...
# 28            WOODRIDGE        CIR   629 WOODRIDGE CIR  Incline Village  ...
# 29            WOODRIDGE        CIR   633 WOODRIDGE CIR  Incline Village  ...
# ...                 ...        ...                 ...              ...  ...
# 64931               NaN        NaN                 NaN              NaN  ...
# 64932               NaN        NaN                 NaN              NaN  ...
# 64933               NaN        NaN                 NaN              NaN  ...
# 64934               NaN        NaN                 NaN              NaN  ...
# 64935               NaN        NaN                 NaN              NaN  ...
# 64936               NaN        NaN                 NaN              NaN  ...
# 64937               NaN        NaN                 NaN              NaN  ...
# 64938               NaN        NaN                 NaN              NaN  ...
# 64939               NaN        NaN                 NaN              NaN  ...
# 64940               NaN        NaN                 NaN              NaN  ...
# 64941               NaN        NaN                 NaN              NaN  ...
# 64942               NaN        NaN                 NaN              NaN  ...
# 64943               NaN        NaN                 NaN              NaN  ...
# 64944               NaN        NaN                 NaN              NaN  ...
# 64945               NaN        NaN                 NaN              NaN  ...
# 64946               NaN        NaN                 NaN              NaN  ...
# 64947               NaN        NaN                 NaN              NaN  ...
# 64948               NaN        NaN                 NaN              NaN  ...
# 64949               NaN        NaN                 NaN              NaN  ...
# 64950               NaN        NaN                 NaN              NaN  ...
# 64951               NaN        NaN                 NaN              NaN  ...
# 64952               NaN        NaN                 NaN              NaN  ...
# 64953               NaN        NaN                 NaN              NaN  ...
# 64954               NaN        NaN                 NaN              NaN  ...
# 64955               NaN        NaN                 NaN              NaN  ...
# 64956               NaN        NaN                 NaN              NaN  ...
# 64957               NaN        NaN                 NaN              NaN  ...
# 64958               NaN        NaN                 NaN              NaN  ...
# 64959               NaN        NaN                 NaN              NaN  ...
# 64960               NaN        NaN                 NaN              NaN  ...
#
#       PublicNotes RelativeErosionHazardScore RunoffPotentialScore SEZLandArea  \
# 0             NaN                        NaN                  NaN         NaN
# 1             NaN                        NaN                  NaN         NaN
# 2             NaN                        NaN                  NaN         NaN
# 3             NaN                        NaN                  NaN         NaN
# 4             NaN                        NaN                  NaN         NaN
# 5             NaN                        NaN                  NaN         NaN
# 6             NaN                        NaN                  NaN         NaN
# 7             NaN                        NaN                  NaN         NaN
# 8                                      326.0                 98.0         0.0
# 9             NaN                        NaN                  NaN         NaN
# 10            NaN                        NaN                  NaN         NaN
# 11            NaN                        NaN                  NaN         NaN
# 12            NaN                        NaN                  NaN         NaN
# 13            NaN                        NaN                  NaN         NaN
# 14            NaN                        NaN                  NaN         NaN
# 15            NaN                        NaN                  NaN         NaN
# 16            NaN                        NaN                  NaN         NaN
# 17            NaN                        NaN                  NaN         NaN
# 18                                     229.0                 81.0         0.0
# 19            NaN                        NaN                  NaN         NaN
# 20            NaN                        NaN                  NaN         NaN
# 21            NaN                        NaN                  NaN         NaN
# 22            NaN                        NaN                  NaN         NaN
# 23            NaN                        NaN                  NaN         NaN
# 24            NaN                        NaN                  NaN         NaN
# 25            NaN                        NaN                  NaN         NaN
# 26            NaN                        NaN                  NaN         NaN
# 27            NaN                        NaN                  NaN         NaN
# 28            NaN                        NaN                  NaN         NaN
# 29            NaN                        NaN                  NaN         NaN
# ...           ...                        ...                  ...         ...
# 64931                                  344.0                 98.0         0.0
# 64932                                  334.0                 81.0         0.0
# 64933                                  346.0                 98.0         0.0
# 64934                                  376.0                 81.0         0.0
# 64935                                  363.0                 81.0         0.0
# 64936                                  372.0                 98.0         0.0
# 64937                                  317.0                 81.0         0.0
# 64938                                  224.0                200.0         0.0
# 64939                                  247.0                 34.0         0.0
# 64940                                  363.0                 44.0         0.0
# 64941                                  347.0                 44.0         0.0
# 64942                                  385.0                 98.0         0.0
# 64943                                  383.0                 98.0         0.0
# 64944                                  214.0                 98.0         0.0
# 64945                                  228.0                 98.0      6800.0
# 64946                                  235.0                 98.0      1035.0
# 64947                                  203.0                 44.0       234.0
# 64948                                  309.0                 98.0         0.0
# 64949                                  239.0                 59.0         0.0
# 64950                                  245.0                 98.0         0.0
# 64951                                  296.0                 98.0         0.0
# 64952                                  315.0                 98.0         0.0
# 64953                                  342.0                 98.0         0.0
# 64954                                  348.0                 44.0      5500.0
# 64955                                  349.0                 44.0         0.0
# 64956                                  344.0                200.0         0.0
# 64957                                  332.0                200.0         0.0
# 64958                                  280.0                 34.0         0.0
# 64959                                  280.0                 34.0         0.0
# 64960                                  277.0                135.0         0.0
#
#       SEZSetbackArea                                      ScoreSheetUrl  \
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
# 5                NaN                                                NaN
# 6                NaN                                                NaN
# 7                NaN                                                NaN
# 8                0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 9                NaN                                                NaN
# 10               NaN                                                NaN
# 11               NaN                                                NaN
# 12               NaN                                                NaN
# 13               NaN                                                NaN
# 14               NaN                                                NaN
# 15               NaN                                                NaN
# 16               NaN                                                NaN
# 17               NaN                                                NaN
# 18               0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 19               NaN                                                NaN
# 20               NaN                                                NaN
# 21               NaN                                                NaN
# 22               NaN                                                NaN
# 23               NaN                                                NaN
# 24               NaN                                                NaN
# 25               NaN                                                NaN
# 26               NaN                                                NaN
# 27               NaN                                                NaN
# 28               NaN                                                NaN
# 29               NaN                                                NaN
# ...              ...                                                ...
# 64931            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64932            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64933            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64934            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64935            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64936            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64937            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64938            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64939            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64940            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64941            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64942            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64943            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64944            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64945        17000.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64946            NaN  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64947            NaN  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64948            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64949            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64950            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64951            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64952            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64953            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64954          600.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64955            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64956            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64957            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64958            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64959            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
# 64960            0.0  https://qa-parcels.laketahoeinfo.org/IpesScore...
#
#          Status TotalParcelArea UtilityInSEZScore  \
# 0           NaN             NaN               NaN
# 1           NaN             NaN               NaN
# 2           NaN             NaN               NaN
# 3           NaN             NaN               NaN
# 4           NaN             NaN               NaN
# 5           NaN             NaN               NaN
# 6           NaN             NaN               NaN
# 7           NaN             NaN               NaN
# 8        Active             NaN             110.0
# 9           NaN             NaN               NaN
# 10          NaN             NaN               NaN
# 11          NaN             NaN               NaN
# 12          NaN             NaN               NaN
# 13          NaN             NaN               NaN
# 14          NaN             NaN               NaN
# 15          NaN             NaN               NaN
# 16          NaN             NaN               NaN
# 17          NaN             NaN               NaN
# 18       Active             NaN             110.0
# 19          NaN             NaN               NaN
# 20          NaN             NaN               NaN
# 21          NaN             NaN               NaN
# 22          NaN             NaN               NaN
# 23          NaN             NaN               NaN
# 24          NaN             NaN               NaN
# 25          NaN             NaN               NaN
# 26          NaN             NaN               NaN
# 27          NaN             NaN               NaN
# 28          NaN             NaN               NaN
# 29          NaN             NaN               NaN
# ...         ...             ...               ...
# 64931  Inactive             NaN             110.0
# 64932  Inactive             NaN             110.0
# 64933  Inactive             NaN             110.0
# 64934  Inactive             NaN             110.0
# 64935  Inactive             NaN             110.0
# 64936  Inactive             NaN             110.0
# 64937  Inactive             NaN             110.0
# 64938  Inactive             NaN             110.0
# 64939  Inactive             NaN             110.0
# 64940  Inactive             NaN             110.0
# 64941  Inactive             NaN             110.0
# 64942  Inactive             NaN             110.0
# 64943  Inactive             NaN             110.0
# 64944  Inactive             NaN             110.0
# 64945  Inactive             NaN             110.0
# 64946  Inactive             NaN             110.0
# 64947  Inactive             NaN             110.0
# 64948  Inactive             NaN             110.0
# 64949  Inactive             NaN             110.0
# 64950  Inactive             NaN             110.0
# 64951  Inactive             NaN             110.0
# 64952  Inactive             NaN             110.0
# 64953  Inactive             NaN             110.0
# 64954  Inactive             NaN              10.0
# 64955  Inactive             NaN             110.0
# 64956  Inactive             NaN             110.0
# 64957  Inactive             NaN             110.0
# 64958  Inactive             NaN             110.0
# 64959  Inactive             NaN             110.0
# 64960  Inactive             NaN             110.0
#
#       WaterQualityImprovementsScore
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 8                              34.0
# 9                               NaN
# 10                              NaN
# 11                              NaN
# 12                              NaN
# 13                              NaN
# 14                              NaN
# 15                              NaN
# 16                              NaN
# 17                              NaN
# 18                             34.0
# 19                              NaN
# 20                              NaN
# 21                              NaN
# 22                              NaN
# 23                              NaN
# 24                              NaN
# 25                              NaN
# 26                              NaN
# 27                              NaN
# 28                              NaN
# 29                              NaN
# ...                             ...
# 64931                          38.0
# 64932                          38.0
# 64933                          38.0
# 64934                          38.0
# 64935                          38.0
# 64936                          38.0
# 64937                          50.0
# 64938                          40.0
# 64939                          40.0
# 64940                          40.0
# 64941                          40.0
# 64942                          34.0
# 64943                          34.0
# 64944                          34.0
# 64945                          34.0
# 64946                          34.0
# 64947                          34.0
# 64948                          28.0
# 64949                          28.0
# 64950                          28.0
# 64951                          28.0
# 64952                          28.0
# 64953                          28.0
# 64954                          28.0
# 64955                          28.0
# 64956                          28.0
# 64957                          28.0
# 64958                          50.0
# 64959                          36.0
# 64960                           4.0
#
# [64961 rows x 87 columns]

# %%
# merge parcel_master and ipes
dfParcelIPES = pd.merge(df1, df2, on='APN', how='outer')
# merge merged retired list
dfParcelIPESRetired = pd.merge(dfParcelIPES, df3, on='APN', how='outer')
# merge zillow listing
dfParcelDevelopment =  pd.merge(dfParcelIPESRetired, df4, on='Address', how='outer')
# view data
dfParcelDevelopment.head()

# %%
dfnotRetired = dfParcelDevelopment.SOURCE.notna()
dfnotRetired.head()

# %%
dfParcelDevelopment.count()

# %%
dfParcelDevelopment.groupby('TRPA_LANDUSE_DESCRIPTION')['APN'].nunique()

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# # Send Email

# %%
# email packages
import smtplib
import mimetypes
from email.mime.multipart import MIMEMultipart
from email import encoders
from email.message import Message
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.image import MIMEImage
from email.mime.text import MIMEText

# %% [markdown]
# ## Data Frames to CSV

# %%
dfLCV.to_csv(r"C:\GIS\PROJECT\LTInfo\Data\dfLCV.csv")

# %%
emailfrom = "mbindl@trpa.org"
emailto = "mbindl@trpa.org"
dataframe = "dfLCV.csv"
fileToSend = ('C:\\GIS\\PROJECT\\LTInfo\\Data\\' + dataframe)
# username = "username"
# password = "password"

msg = MIMEMultipart()
msg["From"] = emailfrom
msg["To"] = emailto
msg["Subject"] = "CSV of Missing APNs"
msg.preamble = "This is a test"

ctype, encoding = mimetypes.guess_type(fileToSend)
if ctype is None or encoding is not None:
    ctype = "application/octet-stream"

maintype, subtype = ctype.split("/", 1)

if maintype == "text":
    fp = open(fileToSend)
    # Note: we should handle calculating the charset
    attachment = MIMEText(fp.read(), _subtype=subtype)
    fp.close()
elif maintype == "image":
    fp = open(fileToSend, "rb")
    attachment = MIMEImage(fp.read(), _subtype=subtype)
    fp.close()
elif maintype == "audio":
    fp = open(fileToSend, "rb")
    attachment = MIMEAudio(fp.read(), _subtype=subtype)
    fp.close()
else:
    fp = open(fileToSend, "rb")
    attachment = MIMEBase(maintype, subtype)
    attachment.set_payload(fp.read())
    fp.close()
    encoders.encode_base64(attachment)
attachment.add_header("Content-Disposition", "attachment", filename="APN_Changes.csv")
msg.attach(attachment)

server = smtplib.SMTP("mail.smtp2go.com", 25)
server.starttls()
# server.login(username,password)
server.sendmail(emailfrom, emailto, msg.as_string())
server.quit()
# Out:
# ---------------------------------------------------------------------------
# SMTPRecipientsRefused                     Traceback (most recent call last)
# <ipython-input-25-b2b818a2854e> in <module>
#      43 server.starttls()
#      44 # server.login(username,password)
# ---> 45 server.sendmail(emailfrom, emailto, msg.as_string())
#      46 server.quit()
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\smtplib.py in sendmail(self, from_addr, to_addrs, msg, mail_options, rcpt_options)
#     879             # the server refused all our recipients
#     880             self._rset()
# --> 881             raise SMTPRecipientsRefused(senderrs)
#     882         (code, resp) = self.data(msg)
#     883         if code != 250:
#
# SMTPRecipientsRefused: {'mbindl@trpa.org': (550, b'relay access denied - please authenticate')}
